# %% [markdown]
# Se instala Kaggle

# %%
# !pip install kaggle==1.5.12
# Out:
# Collecting kaggle==1.5.12
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 1.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle==1.5.12) (1.17.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from kaggle==1.5.12) (2025.6.15)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle==1.5.12) (2.9.0.post0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle==1.5.12) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle==1.5.12) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle==1.5.12) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle==1.5.12) (2.4.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle==1.5.12) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle==1.5.12) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle==1.5.12) (3.10)
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73026 sha256=6ef7d4ea8de9dc52e320359653bc0b02dc7dc128a4abbf4d5af2794b8eb84240
#   Stored in directory: /root/.cache/pip/wheels/2e/27/39/f44e52756a6407b444143f233abe9fda0e18a23e8b20e0cd1c
# Successfully built kaggle
# Installing collected packages: kaggle
#   Attempting uninstall: kaggle
#     Found existing installation: kaggle 1.7.4.5
#     Uninstalling kaggle-1.7.4.5:
#       Successfully uninstalled kaggle-1.7.4.5
# Successfully installed kaggle-1.5.12

# %% [markdown]
# Es necesario ubicar el archivo de autenticación de Kaggle en la dirección luego de ser cargados a la carpeta de archivos de Colab.

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Se descarga el dataset

# %%
# !kaggle competitions download -c udea-ai-4-eng-20251-pruebas-saber-pro-colombia
# Out:
# Downloading udea-ai-4-eng-20251-pruebas-saber-pro-colombia.zip to /content
#  64% 19.0M/29.9M [00:00<00:00, 163MB/s]
# 100% 29.9M/29.9M [00:00<00:00, 200MB/s]

# %% [markdown]
# Se descomprime el dataset

# %%
# !unzip /content/udea-ai-4-eng-20251-pruebas-saber-pro-colombia.zip
# Out:
# Archive:  /content/udea-ai-4-eng-20251-pruebas-saber-pro-colombia.zip
#   inflating: submission_example.csv
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# Se instala CatBoost (modelo que se utilizará para la clasificación)

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (8.5.0)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 7.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %% [markdown]
# Importación de librerías

# %%
import pandas as pd
import numpy as np
import unicodedata
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
import sklearn.model_selection
import sklearn.metrics
from sklearn.feature_selection import RFECV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from catboost import CatBoostClassifier

# %% [markdown]
# Se carga el archivo de para realizar inferencia de datos. Debido a que el archivo es de extensión .csv se utiliza la rutina de pandas **read_csv**

# %%
train_dataset = pd.read_csv('/content/train.csv')

# %% [markdown]
# Se crean las funciones para realizar todo el preprocesado para ingresar los datos al modelo, tanto entrenamiento como inferencia. Inicialmente, se crea la función para la estandarización de nos nombres de los departamentos, para luego pasarlos a regiones.

# %%
def limpiar_nombre(nombre):
    if pd.isna(nombre):
        return None

    nombre_normalizado = unicodedata.normalize('NFD', str(nombre).upper())
    nombre_limpio = "".join(c for c in nombre_normalizado if unicodedata.category(c) != 'Mn')

    # Reemplazos para estandarizar los nombres

    if 'BOGOTA' in nombre_limpio:
        return 'SANTAFE DE BOGOTA D.C'

    if 'SAN ANDRES' in nombre_limpio:
        return 'ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA CATALINA'

    if 'NARINO' in nombre_limpio:
        return 'NARIÑO'

    if 'VALLE' in nombre_limpio:
        return 'VALLE DEL CAUCA'

    if 'NORTE SANTANDER' in nombre_limpio:
        return 'NORTE DE SANTANDER'

    return nombre_limpio.strip()

# %%
mapa_departamento_a_region = {
    'AMAZONAS': 'Amazonía',
    'ANTIOQUIA': 'Andina',
    'ARAUCA': 'Orinoquía',
    'ATLANTICO': 'Caribe', # Limpiado de 'ATLÁNTICO'
    'SANTAFE DE BOGOTA D.C': 'Andina', # Nombre estandarizado para Bogotá
    'BOLIVAR': 'Caribe',    # Limpiado de 'BOLÍVAR'
    'BOYACA': 'Andina',     # Limpiado de 'BOYACÁ'
    'CALDAS': 'Andina',
    'CAQUETA': 'Amazonía',  # Limpiado de 'CAQUETÁ'
    'CASANARE': 'Orinoquía',
    'CAUCA': 'Pacífica', # Principalmente Pacífica, aunque tiene parte Andina
    'CESAR': 'Caribe',
    'CHOCO': 'Pacífica',    # Limpiado de 'CHOCÓ'
    'CORDOBA': 'Caribe',    # Limpiado de 'CÓRDOBA'
    'CUNDINAMARCA': 'Andina',
    'GUAINIA': 'Amazonía',  # Limpiado de 'GUAINÍA'
    'GUAVIARE': 'Amazonía',
    'HUILA': 'Andina',
    'LA GUAJIRA': 'Caribe',
    'MAGDALENA': 'Caribe',
    'META': 'Orinoquía',
    'NARIÑO': 'Pacífica', # Principalmente Pacífica, aunque tiene parte Andina
    'NORTE DE SANTANDER': 'Andina',
    'PUTUMAYO': 'Amazonía',
    'QUINDIO': 'Andina',    # Limpiado de 'QUINDÍO'
    'RISARALDA': 'Andina',
    'ARCHIPIELAGO DE SAN ANDRES PROVIDENCIA Y SANTA CATALINA': 'Insular', # Nombre estandarizado
    'SANTANDER': 'Andina',
    'SUCRE': 'Caribe',
    'TOLIMA': 'Andina',
    'VALLE DEL CAUCA': 'Pacífica',
    'VAUPES': 'Amazonía',   # Limpiado de 'VAUPÉS'
    'VICHADA': 'Orinoquía'
}

# %%
def normalize_text(text):

    # Se normaliza el texto

    if not isinstance(text, str):
        return ""
    try:
        text = text.upper()
        text = ''.join(c for c in unicodedata.normalize('NFD', text)
                       if unicodedata.category(c) != 'Mn')
    except Exception: # Por si acaso hay algún valor inesperado
        return ""
    return text

# %% [markdown]
# Se crea el diccionario para la agrupación por facultades

# %%
faculty_map = {

    'EDUCACION_PEDAGOGIA': ['LICENCIATURA', 'PEDAGOGIA', 'PEDAGOGÍA', 'NORMALISTA', 'ENSEÑANZA', 'DIDACTICA', 'ETNOEDUCACION'],
    'CIENCIAS_SALUD': [
        'MEDICINA', 'ENFERMERIA', 'ODONTOLOGIA', 'VETERINARIA', 'FISIOTERAPIA', 'NUTRICION', 'DIETETICA',
        'SALUD OCUPACIONAL', 'SALUD EN EL TRABAJO', 'SEGURIDAD Y SALUD EN EL TRABAJO',
        'QUIMICA FARMACEUTICA', 'FARMACIA', 'INSTRUMENTACION QUIRURGICA', 'OPTOMETRIA',
        'TERAPIA RESPIRATORIA', 'TERAPIA OCUPACIONAL', 'BACTERIOLOGIA', 'FONOAUDIOLOGIA', 'GERONTOLOGIA',
        'SALUD PUBLICA', 'BIOANALISIS', 'EPIDEMIOLOGIA', 'SALUD',
        'TERAPIAS PSICOSOCIALES', 'TERAPIA CARDIORRESPIRATORIA', 'SALUD ORAL', 'QUIRURGICA', 'FARMAC¿UTICA'
    ],
    'INGENIERIA_TECNOLOGIA': [
        'INGENIERI', 'SISTEMAS', 'SOFTWARE', 'TELECOMUNIC', 'TECNOLOGI', 'COMPUTACION', 'INFORMATICA',
        'MECANICA', 'CIVIL', 'INDUSTRIAL', 'ELECTRONICA', 'ELECTRICA', 'QUIMICA',
        'ALIMENTOS', 'PRODUCCION', 'MECATRONICA', 'BIOMEDICA', 'CONTROL', 'PROCESOS', 'AGROINDUSTRIAL',
        'MULTIMEDIA', 'SONIDO', 'PETROLEO', 'AERONAUTICA', 'NAVAL', 'TOPOGRAFIA', 'MATERIALES', 'GEOLOGICA',
        'FORESTAL', 'ELECTROMECANICA', 'TELEMATICA', 'ENERGIA', 'AGRICOLA', 'MINAS',
        'CATASTRAL', 'AUTOMATIZACION', 'PLASTICOS', 'TEXTIL', 'MANTENIMIENTO', 'BIOQUIMICA',
        'BIOTECNOLOGICA', 'OCEANOGRAFICA', 'URBANA', 'PETROQUIMICA', 'NANOTECNOLOGIA',
        'CIENCIA DE DATOS', 'INTELIGENCIA ARTIFICIAL', 'ROBOTICA', 'DESARROLLO DE SOFTWARE',
        'CONSTRUCCION', 'CIENCIAS DE LA INFORMACION Y LA DOCUMENTACION', 'INGENIER¿A', 'URBANISMO'
    ],
    'ARTES_DISENO_COM_AUDIOVISUAL': [
        'ARTE', 'ARTES', 'DISEÑO', 'DISENO', 'MUSICA', 'ARQUITECTURA', 'COMUNICACION AUDIOVISUAL', 'AUDIOVISUAL',
        'VISUAL', 'CINE', 'TELEVISION', 'FOTOGRAFIA', 'MODA', 'VESTUARIO', 'DANZA', 'TEATRO',
        'INTERIORES', 'ESCENARIOS', 'ANIMACION', 'CULINARIA', 'GASTRONOMIA', 'REALIZACION',
        'PRODUCCION MUSICAL', 'BELLAS ARTES', 'MEDIOS AUDIOVISUALES', 'COMUNICACION GRAFICA', 'GRAFICO',
        'PUBLICIDAD', 'ESCENICAS', 'PLASTICAS', 'COREOGRAFICA', 'PATRIMONIO', 'CREACION LITERARIA',
        'INTERACTIVO', 'CROSSMEDIA', 'NARRATIVAS DIGITALES', 'COMUNICACION', 'COMUNICACI¿N', 'DISE¿¿O'
    ],
    'CIENCIAS_ECONOMICAS_ADMINISTRATIVAS_CONTABLES': [
        'ADMINISTRA', 'MERCADEO', 'FINANCIERA', 'CONTADURIA', 'ECONOMIA', 'NEGOCIOS', 'COMERCIO',
        'HOTELERIA', 'TURISMO', 'GESTION', 'LOGISTICA', 'FINANZAS', 'BANCARIA', 'EMPRESARIAL',
        'AUDITORIA', 'TRIBUTARIA', 'GERENCIA', 'COMERCIAL', 'ADUANAS', 'SEGUROS', 'ADMINSITRACION', 'ECONOM¿A', 'MARKETING',
        'MERCADOLOGIA', 'RELACIONES ECONOMICAS INTERNACIONALES'
    ],
    'CIENCIAS_SOCIALES_HUMANIDADES_DERECHO': [
        'DERECHO', 'JURISPRUDENCIA', 'PSICOLOGIA', 'CIENCIA POLITICA', 'POLITICA', 'COMUNICACION SOCIAL',
        'PERIODISMO', 'TRABAJO SOCIAL', 'SOCIOLOGIA', 'FILOSOFIA', 'HISTORIA', 'ANTROPOLOGIA', 'GEOGRAFIA',
        'RELACIONES INTERNACIONALES', 'ESTUDIOS LITERARIOS', 'LITERATURA', 'LINGUISTICA', 'FILOLOGIA',
        'ARCHIVISTICA', 'BIBLIOTECOLOGIA', 'TEOLOGIA', 'PLANEACION Y DESARROLLO SOCIAL', 'CRIMINALISTICA',
        'GOBIERNO', 'ESTUDIOS POLITICOS', 'DESARROLLO FAMILIAR', 'HUMANIDADES', 'LETRAS', 'SOCIOCULTURALES',
        'PAZ', 'CONFLICTO', 'DERECHOS HUMANOS', 'ESTUDIOS CULTURALES', 'COOPERACION INTERNACIONAL',
        'CIENCIAS RELIGIOSAS', 'RELACIONES PUBLICAS', 'COMUNICACION CORPORATIVA', 'ARQUEOLOGIA', 'CIENCIAS BIBLICAS',
        'DEPOR', 'LENGUAS', 'PSICÓLOGA'
    ],
    'CIENCIAS_AGROPECUARIAS_AMBIENTALES': [
        'AGRONOMIA', 'AGROPECUARIA', 'ZOOTECNIA', 'AGROFORESTAL', 'PESQUERA', 'ACUICULTURA', 'AGRONEGOCIOS',
        'AMBIENTAL', 'ECOLOGIA', 'RECURSOS NATURALES', 'DESARROLLO RURAL', 'AGROECOLOGICA', 'AGROINDUSTRIA'
    ],
    'CIENCIAS_EXACTAS_NATURALES': [
        'ESTADISTICA', 'BIOLOGIA', 'QUIMICA',
        'MATEMATICAS', 'FISICA', 'GEOLOGIA',
        'MICROBIOLOGIA', 'GEOCIENCIAS', 'ASTRONOMIA', 'OCEANOGRAFIA',
        'BIOQUIMICA', 'BIOTECNOLOGIA',
        'CIENCIAS NATURALES', 'CIENCIAS DE LA COMPUTACION',
        'ACTUARIA', 'GEOGRAFIA FISICA', 'GEOLOG¿A', 'MATEM'
    ],
    'DEFENSA_SEGURIDAD': [
        'CIENCIAS MILITARES', 'CIENCIAS NAVALES', 'ADMINISTRACION POLICIAL', 'INVESTIGACION CRIMINAL',
        'SEGURIDAD',
    ]
}

# %%
faculty_order = [
    'EDUCACION_PEDAGOGIA',
    'CIENCIAS_SALUD',
    'INGENIERIA_TECNOLOGIA',
    'ARTES_DISENO_COM_AUDIOVISUAL',
    'CIENCIAS_ECONOMICAS_ADMINISTRATIVAS_CONTABLES',
    'CIENCIAS_SOCIALES_HUMANIDADES_DERECHO',
    'CIENCIAS_AGROPECUARIAS_AMBIENTALES',
    'CIENCIAS_EXACTAS_NATURALES',
    'DEFENSA_SEGURIDAD'
]

# %% [markdown]
# Se crea la función para asignar las facultades

# %%
def get_faculty(program_name_raw):

    program_name = normalize_text(program_name_raw)

    if not program_name:
        return 'OTROS_PROGRAMAS_O_INVALIDOS'

    if 'QUIMICA FARMACEUTICA' in program_name:
        return 'CIENCIAS_SALUD'

    if 'INGENIERIA QUIMICA' in program_name:
        return 'INGENIERIA_TECNOLOGIA'

    health_safety_phrases = [
        'SEGURIDAD Y SALUD EN EL TRABAJO', 'SALUD OCUPACIONAL', 'ADMINISTRACION EN SALUD OCUPACIONAL',
        'ADMINISTRACION DE LA SEGURIDAD Y SALUD OCUPACIONAL', 'ADMINISTRACION DE LA SEGURIDAD SOCIAL',
        'GESTION DE LA SEGURIDAD Y LA SALUD LABORAL', 'RIESGOS DE SEGURIDAD Y SALUD EN EL TRABAJO',
        'HIGIENE Y SEGURIDAD OCUPACIONAL', 'SEGURIDAD Y SALUD PARA EL TRABAJO',
        'SEGURIDAD INDUSTRIAL E HIGIENE OCUPACIONAL', 'SALUD LABORAL'
    ]

    for phrase in health_safety_phrases:
        if phrase in program_name:
            return 'CIENCIAS_SALUD'

    if 'CONSTRUCCION' in program_name:

        if 'ARQUITECTURA' in program_name or 'ARQUITECTONICA' in program_name:

            return 'ARTES_DISENO_COM_AUDIOVISUAL'
        else:
            return 'INGENIERIA_TECNOLOGIA'

    if 'CIENCIAS DE LA COMPUTACION' in program_name:

        if 'INTELIGENCIA ARTIFICIAL' in program_name or 'INGENIERIA' in program_name:

            return 'INGENIERIA_TECNOLOGIA'

        else:

            return 'INGENIERIA_TECNOLOGIA'

    if 'PUBLICIDAD' in program_name:

        if 'MERCADEO' in program_name or 'VENTAS' in program_name or 'COMERCIAL' in program_name or 'NEGOCIOS' in program_name or 'MARKETING' in program_name:

            return 'CIENCIAS_ECONOMICAS_ADMINISTRATIVAS_CONTABLES'

    # --- Bucle General por Palabras Clave ---

    for faculty_name in faculty_order:
        keywords = faculty_map[faculty_name]
        for keyword in keywords:
            if keyword in program_name:
                if faculty_name == 'INGENIERIA_TECNOLOGIA':
                    if keyword == 'QUIMICA' and 'FARMACEUTICA' in program_name: continue
                elif faculty_name == 'CIENCIAS_EXACTAS_NATURALES':
                    if keyword == 'QUIMICA' and ('FARMACEUTICA' in program_name or 'INGENIERI' in program_name): continue
                    if keyword == 'GEOLOGIA' and 'INGENIERI' in program_name: continue
                    if (keyword == 'BIOQUIMICA' or keyword == 'BIOTECNOLOGIA') and 'INGENIERI' in program_name: continue
                    if keyword == 'CIENCIAS DE LA COMPUTACION' and ('INGENIERI' in program_name or 'INTELIGENCIA ARTIFICIAL' in program_name): continue
                elif faculty_name == 'CIENCIAS_AGROPECUARIAS_AMBIENTALES':
                    if (keyword == 'AGROINDUSTRIAL' or keyword == 'AGROINDUSTRIA') and 'INGENIERI' in program_name: continue
                if keyword == 'SALUD' and 'ADMINISTRA' in program_name and faculty_name == 'CIENCIAS_SALUD':
                    return 'CIENCIAS_SALUD'

                return faculty_name

    return 'OTROS_PROGRAMAS_NO_CLASIFICADOS' # Para programas que no coincidan con ninguna palabra clave

# %%
def preprocess_data(df, train=True):

  # Eliminación de columnas innecesarias

  ids = df.pop('ID') # Se conserva ID para el caso de los datos de test

  df.drop(['PERIODO', 'coef_4'],
          axis=1,
          inplace=True)

  # Llenado de datos faltantes

  df['FAMI_ESTRATOVIVIENDA'] = df['FAMI_ESTRATOVIVIENDA'].fillna('Sin Estrato')
  df['ESTU_VALORMATRICULAUNIVERSIDAD'] = df['ESTU_VALORMATRICULAUNIVERSIDAD'].fillna('No aplica')

  # Se asignan las categorías posibles para la variable ESTU_VALORMATRICULAUNIVERSIDAD
  orden_matricula = [
    'No pagó matrícula',
    'Menos de 500 mil',
    'Entre 500 mil y menos de 1 millón',
    'Entre 1 millón y menos de 2.5 millones',
    'Entre 2.5 millones y menos de 4 millones',
    'Entre 4 millones y menos de 5.5 millones',
    'Entre 5.5 millones y menos de 7 millones',
    'Más de 7 millones',
    'No aplica'
  ]

  df['ESTU_VALORMATRICULAUNIVERSIDAD'] = pd.Categorical(
    df['ESTU_VALORMATRICULAUNIVERSIDAD'],
    categories=orden_matricula,
    ordered=True
  )

  # Preprocesamiento para extraer la región

  df['ESTU_PRGM_DEPARTAMENTO'] = df['ESTU_PRGM_DEPARTAMENTO'].apply(limpiar_nombre)
  df['ESTU_PRGM_REGION'] = df['ESTU_PRGM_DEPARTAMENTO'].map(mapa_departamento_a_region)
  df.drop('ESTU_PRGM_DEPARTAMENTO', inplace=True, axis=1)

  # Preprocesamiento para extraer la facultad

  df['FACULTAD'] = df['ESTU_PRGM_ACADEMICO'].apply(get_faculty)
  df.drop('ESTU_PRGM_ACADEMICO', inplace=True, axis=1)

  # Asignación de categorías de ESTU_HORASSEMANATRABAJA

  orden_horas = [
    '0',
    'Menos de 10 horas',
    'Entre 11 y 20 horas',
    'Entre 21 y 30 horas',
    'Más de 30 horas',
    'No aplica'
  ]

  df['ESTU_HORASSEMANATRABAJA'] = pd.Categorical(
    df['ESTU_HORASSEMANATRABAJA'],
    categories=orden_horas,
    ordered=True
  )

  # Llenado de datos faltantes y eliminación de caracteristicas innecesarias

  df.drop('FAMI_TIENEINTERNET.1', axis=1, inplace=True)
  df['FAMI_TIENEINTERNET'] = df['FAMI_TIENEINTERNET'].fillna('No')

  df.drop('FAMI_TIENELAVADORA', axis=1, inplace=True)

  df.drop('FAMI_TIENECOMPUTADOR', axis=1, inplace=True)

  df['FAMI_TIENEAUTOMOVIL'] = df['FAMI_TIENEAUTOMOVIL'].fillna('No')

  mapeo_reemplazo_strings = {
    'No sabe': 'No aplica',
  }

  df['FAMI_EDUCACIONPADRE'] = df['FAMI_EDUCACIONPADRE'].replace(mapeo_reemplazo_strings)
  df['FAMI_EDUCACIONPADRE'] = df['FAMI_EDUCACIONPADRE'].fillna('No aplica')

  df['FAMI_EDUCACIONMADRE'] = df['FAMI_EDUCACIONMADRE'].replace(mapeo_reemplazo_strings)
  df['FAMI_EDUCACIONMADRE'] = df['FAMI_EDUCACIONMADRE'].fillna('No aplica')

  df['ESTU_HORASSEMANATRABAJA'] = df['ESTU_HORASSEMANATRABAJA'].fillna('No aplica')
  df['ESTU_PAGOMATRICULAPROPIO'] = df['ESTU_PAGOMATRICULAPROPIO'].fillna('No')

  columnas_codificar = ['ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_HORASSEMANATRABAJA',
        'FAMI_TIENEINTERNET', 'FAMI_EDUCACIONPADRE', 'FAMI_TIENEAUTOMOVIL',
        'ESTU_PRIVADO_LIBERTAD', 'ESTU_PAGOMATRICULAPROPIO', 'FAMI_EDUCACIONMADRE',
        'ESTU_PRGM_REGION', 'FACULTAD'
  ]

  # One-hot encoding

  encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

  datos_para_codificar = df[columnas_codificar]
  datos_codificados_array = encoder.fit_transform(datos_para_codificar)
  nombres_nuevas_columnas = encoder.get_feature_names_out(input_features=columnas_codificar)

  df_codificado = pd.DataFrame(
    datos_codificados_array,
    columns=nombres_nuevas_columnas,
    index=df.index
  )

  df.drop(columns=columnas_codificar, inplace=True)
  df = pd.concat([df, df_codificado], axis=1)

  # Codificación ordinal

  orden_estratos = ['Sin Estrato', 'Estrato 1', 'Estrato 2', 'Estrato 3', 'Estrato 4', 'Estrato 5', 'Estrato 6']

  ord_encoder = OrdinalEncoder(
    categories=[orden_estratos],
    handle_unknown='use_encoded_value',
    unknown_value=np.nan
  )

  df['FAMI_ESTRATOVIVIENDA'] = encoder.fit_transform(df[['FAMI_ESTRATOVIVIENDA']])

  if train:

    columna_extraida = df.pop('RENDIMIENTO_GLOBAL')
    df['RENDIMIENTO_GLOBAL'] = columna_extraida


    orden_rendimiento = [
        'alto',
        'medio-alto',
        'medio-bajo',
        'bajo'
    ]


    ord_encoder_1 = OrdinalEncoder(
      categories=[orden_rendimiento],
      handle_unknown='use_encoded_value',
      unknown_value=np.nan
    )


    df['RENDIMIENTO_GLOBAL'] = ord_encoder_1.fit_transform(df[['RENDIMIENTO_GLOBAL']])

    return df, ord_encoder_1

  else:

    return ids, df

# %% [markdown]
# Se cargan los datasets

# %%
train_dataset = pd.read_csv('/content/train.csv')
test_dataset = pd.read_csv('/content/test.csv')

# %%
data, target_encoder = preprocess_data(train_dataset)
X = data.drop('RENDIMIENTO_GLOBAL', axis=1)
y = data['RENDIMIENTO_GLOBAL']

# %% [markdown]
# Definición y entrenamiento del modelo

# %%
model = CatBoostClassifier(iterations=500, learning_rate=0.1, depth=6, verbose=2)

# %%
cv_strategy = StratifiedKFold(n_splits=3)  # Use stratified folds for classification

rfecv_selector = RFECV(
    estimator=model,
    step=4,                          # Remove one feature at each step
    cv=cv_strategy,                  # Cross-validation strategy
    scoring='accuracy',              # Metric to evaluate feature subsets
    min_features_to_select=1,        # Minimum number of features to consider
    n_jobs=-1                        # Use all available CPU cores
)

# %%
rfecv_selector.fit(X, y)
# Out:
# 0:	learn: 1.3684187	total: 595ms	remaining: 4m 56s
# 2:	learn: 1.3438669	total: 1.36s	remaining: 3m 45s
# 4:	learn: 1.3263125	total: 2.09s	remaining: 3m 27s
# 6:	learn: 1.3136340	total: 2.8s	remaining: 3m 17s
# 8:	learn: 1.3042335	total: 3.49s	remaining: 3m 10s
# 10:	learn: 1.2968056	total: 4.2s	remaining: 3m 6s
# 12:	learn: 1.2903209	total: 4.87s	remaining: 3m 2s
# 14:	learn: 1.2851440	total: 5.57s	remaining: 3m
# 16:	learn: 1.2807720	total: 6.71s	remaining: 3m 10s
# 18:	learn: 1.2771271	total: 8.07s	remaining: 3m 24s
# 20:	learn: 1.2740355	total: 9.03s	remaining: 3m 25s
# 22:	learn: 1.2714216	total: 9.73s	remaining: 3m 21s
# 24:	learn: 1.2692652	total: 10.4s	remaining: 3m 17s
# 26:	learn: 1.2669453	total: 11.1s	remaining: 3m 13s
# 28:	learn: 1.2650997	total: 11.7s	remaining: 3m 10s
# 30:	learn: 1.2632723	total: 12.3s	remaining: 3m 6s
# 32:	learn: 1.2617354	total: 13.1s	remaining: 3m 4s
# 34:	learn: 1.2605767	total: 13.7s	remaining: 3m 2s
# 36:	learn: 1.2594988	total: 14.4s	remaining: 3m
# 38:	learn: 1.2585680	total: 15.1s	remaining: 2m 58s
# 40:	learn: 1.2575917	total: 15.7s	remaining: 2m 56s
# 42:	learn: 1.2565882	total: 16.4s	remaining: 2m 54s
# 44:	learn: 1.2559324	total: 17.1s	remaining: 2m 52s
# 46:	learn: 1.2553164	total: 17.7s	remaining: 2m 50s
# 48:	learn: 1.2546160	total: 18.4s	remaining: 2m 49s
# 50:	learn: 1.2540860	total: 19.3s	remaining: 2m 49s
# 52:	learn: 1.2534945	total: 20.5s	remaining: 2m 52s
# 54:	learn: 1.2528023	total: 21.8s	remaining: 2m 55s
# 56:	learn: 1.2523195	total: 22.5s	remaining: 2m 54s
# 58:	learn: 1.2517942	total: 23.1s	remaining: 2m 52s
# 60:	learn: 1.2513902	total: 23.8s	remaining: 2m 50s
# 62:	learn: 1.2510596	total: 24.4s	remaining: 2m 49s
# 64:	learn: 1.2506500	total: 25.1s	remaining: 2m 47s
# 66:	learn: 1.2503324	total: 25.8s	remaining: 2m 46s
# 68:	learn: 1.2499454	total: 26.4s	remaining: 2m 45s
# 70:	learn: 1.2495576	total: 27.1s	remaining: 2m 43s
# 72:	learn: 1.2492389	total: 27.7s	remaining: 2m 42s
# 74:	learn: 1.2488658	total: 28.4s	remaining: 2m 40s
# 76:	learn: 1.2486032	total: 29.1s	remaining: 2m 39s
# 78:	learn: 1.2483099	total: 29.7s	remaining: 2m 38s
# 80:	learn: 1.2481211	total: 30.4s	remaining: 2m 37s
# 82:	learn: 1.2477348	total: 31s	remaining: 2m 35s
# 84:	learn: 1.2474461	total: 31.8s	remaining: 2m 35s
# 86:	learn: 1.2472183	total: 32.8s	remaining: 2m 35s
# 88:	learn: 1.2469494	total: 33.9s	remaining: 2m 36s
# 90:	learn: 1.2467068	total: 35.1s	remaining: 2m 37s
# 92:	learn: 1.2464980	total: 35.8s	remaining: 2m 36s
# 94:	learn: 1.2463186	total: 36.4s	remaining: 2m 35s
# 96:	learn: 1.2460250	total: 37.1s	remaining: 2m 34s
# 98:	learn: 1.2458619	total: 37.8s	remaining: 2m 32s
# 100:	learn: 1.2457069	total: 38.4s	remaining: 2m 31s
# 102:	learn: 1.2455017	total: 39.1s	remaining: 2m 30s
# 104:	learn: 1.2453640	total: 39.7s	remaining: 2m 29s
# 106:	learn: 1.2452228	total: 40.4s	remaining: 2m 28s
# 108:	learn: 1.2450234	total: 41.5s	remaining: 2m 28s
# 110:	learn: 1.2449094	total: 42.6s	remaining: 2m 29s
# 112:	learn: 1.2446631	total: 43.8s	remaining: 2m 29s
# 114:	learn: 1.2444830	total: 44.5s	remaining: 2m 28s
# 116:	learn: 1.2443201	total: 45.1s	remaining: 2m 27s
# 118:	learn: 1.2441301	total: 46.3s	remaining: 2m 28s
# 120:	learn: 1.2438711	total: 47.5s	remaining: 2m 28s
# 122:	learn: 1.2437264	total: 48.7s	remaining: 2m 29s
# 124:	learn: 1.2435697	total: 49.3s	remaining: 2m 27s
# 126:	learn: 1.2434234	total: 50s	remaining: 2m 26s
# 128:	learn: 1.2432852	total: 50.7s	remaining: 2m 25s
# 130:	learn: 1.2431160	total: 51.3s	remaining: 2m 24s
# 132:	learn: 1.2429872	total: 52s	remaining: 2m 23s
# 134:	learn: 1.2428251	total: 52.6s	remaining: 2m 22s
# 136:	learn: 1.2427025	total: 53.3s	remaining: 2m 21s
# 138:	learn: 1.2425682	total: 54s	remaining: 2m 20s
# 140:	learn: 1.2424157	total: 54.6s	remaining: 2m 19s
# 142:	learn: 1.2422939	total: 55.3s	remaining: 2m 17s
# 144:	learn: 1.2421245	total: 56s	remaining: 2m 16s
# 146:	learn: 1.2420126	total: 56.6s	remaining: 2m 15s
# 148:	learn: 1.2418799	total: 57.3s	remaining: 2m 14s
# 150:	learn: 1.2417525	total: 58s	remaining: 2m 13s
# 152:	learn: 1.2416258	total: 58.6s	remaining: 2m 12s
# 154:	learn: 1.2414617	total: 59.8s	remaining: 2m 13s
# 156:	learn: 1.2413104	total: 1m	remaining: 2m 13s
# 158:	learn: 1.2411917	total: 1m 1s	remaining: 2m 12s
# 160:	learn: 1.2410376	total: 1m 2s	remaining: 2m 11s
# 162:	learn: 1.2408641	total: 1m 3s	remaining: 2m 11s
# 164:	learn: 1.2407176	total: 1m 4s	remaining: 2m 10s
# 166:	learn: 1.2405966	total: 1m 4s	remaining: 2m 9s
# 168:	learn: 1.2404802	total: 1m 5s	remaining: 2m 8s
# 170:	learn: 1.2404103	total: 1m 6s	remaining: 2m 6s
# 172:	learn: 1.2402928	total: 1m 6s	remaining: 2m 5s
# 174:	learn: 1.2401818	total: 1m 7s	remaining: 2m 4s
# 176:	learn: 1.2400480	total: 1m 7s	remaining: 2m 4s
# 178:	learn: 1.2399542	total: 1m 8s	remaining: 2m 3s
# 180:	learn: 1.2398586	total: 1m 9s	remaining: 2m 2s
# 182:	learn: 1.2397645	total: 1m 9s	remaining: 2m 1s
# 184:	learn: 1.2396664	total: 1m 10s	remaining: 2m
# 186:	learn: 1.2395877	total: 1m 11s	remaining: 1m 59s
# 188:	learn: 1.2395022	total: 1m 11s	remaining: 1m 58s
# 190:	learn: 1.2394268	total: 1m 13s	remaining: 1m 58s
# 192:	learn: 1.2393214	total: 1m 14s	remaining: 1m 58s
# 194:	learn: 1.2392111	total: 1m 15s	remaining: 1m 57s
# 196:	learn: 1.2391039	total: 1m 15s	remaining: 1m 56s
# 198:	learn: 1.2390043	total: 1m 16s	remaining: 1m 55s
# 200:	learn: 1.2388994	total: 1m 17s	remaining: 1m 54s
# 202:	learn: 1.2388180	total: 1m 17s	remaining: 1m 53s
# 204:	learn: 1.2387502	total: 1m 18s	remaining: 1m 52s
# 206:	learn: 1.2386827	total: 1m 19s	remaining: 1m 52s
# 208:	learn: 1.2385847	total: 1m 19s	remaining: 1m 51s
# 210:	learn: 1.2384923	total: 1m 20s	remaining: 1m 50s
# 212:	learn: 1.2384324	total: 1m 21s	remaining: 1m 49s
# 214:	learn: 1.2383530	total: 1m 21s	remaining: 1m 48s
# 216:	learn: 1.2382772	total: 1m 22s	remaining: 1m 47s
# 218:	learn: 1.2381776	total: 1m 23s	remaining: 1m 46s
# 220:	learn: 1.2380879	total: 1m 23s	remaining: 1m 45s
# 222:	learn: 1.2380080	total: 1m 24s	remaining: 1m 44s
# 224:	learn: 1.2379301	total: 1m 25s	remaining: 1m 44s
# 226:	learn: 1.2378297	total: 1m 26s	remaining: 1m 44s
# 228:	learn: 1.2377626	total: 1m 27s	remaining: 1m 43s
# 230:	learn: 1.2376967	total: 1m 28s	remaining: 1m 43s
# 232:	learn: 1.2376222	total: 1m 29s	remaining: 1m 42s
# 234:	learn: 1.2375518	total: 1m 29s	remaining: 1m 41s
# 236:	learn: 1.2374930	total: 1m 30s	remaining: 1m 40s
# 238:	learn: 1.2374278	total: 1m 31s	remaining: 1m 39s
# 240:	learn: 1.2373789	total: 1m 31s	remaining: 1m 38s
# 242:	learn: 1.2373175	total: 1m 32s	remaining: 1m 37s
# 244:	learn: 1.2372646	total: 1m 33s	remaining: 1m 36s
# 246:	learn: 1.2371699	total: 1m 33s	remaining: 1m 36s
# 248:	learn: 1.2370864	total: 1m 34s	remaining: 1m 35s
# 250:	learn: 1.2370135	total: 1m 35s	remaining: 1m 34s
# 252:	learn: 1.2369598	total: 1m 35s	remaining: 1m 33s
# 254:	learn: 1.2368915	total: 1m 36s	remaining: 1m 32s
# 256:	learn: 1.2368157	total: 1m 37s	remaining: 1m 31s
# 258:	learn: 1.2367461	total: 1m 37s	remaining: 1m 31s
# 260:	learn: 1.2366961	total: 1m 38s	remaining: 1m 30s
# 262:	learn: 1.2366463	total: 1m 39s	remaining: 1m 29s
# 264:	learn: 1.2365719	total: 1m 41s	remaining: 1m 29s
# 266:	learn: 1.2365128	total: 1m 41s	remaining: 1m 28s
# 268:	learn: 1.2364380	total: 1m 42s	remaining: 1m 28s
# 270:	learn: 1.2363867	total: 1m 43s	remaining: 1m 27s
# 272:	learn: 1.2363169	total: 1m 43s	remaining: 1m 26s
# 274:	learn: 1.2362395	total: 1m 44s	remaining: 1m 25s
# 276:	learn: 1.2361856	total: 1m 45s	remaining: 1m 24s
# 278:	learn: 1.2361381	total: 1m 45s	remaining: 1m 23s
# 280:	learn: 1.2360908	total: 1m 46s	remaining: 1m 23s
# 282:	learn: 1.2360385	total: 1m 47s	remaining: 1m 22s
# 284:	learn: 1.2359797	total: 1m 47s	remaining: 1m 21s
# 286:	learn: 1.2359237	total: 1m 48s	remaining: 1m 20s
# 288:	learn: 1.2358811	total: 1m 49s	remaining: 1m 19s
# 290:	learn: 1.2358228	total: 1m 49s	remaining: 1m 18s
# 292:	learn: 1.2357612	total: 1m 50s	remaining: 1m 18s
# 294:	learn: 1.2356950	total: 1m 51s	remaining: 1m 17s
# 296:	learn: 1.2356489	total: 1m 52s	remaining: 1m 16s
# 298:	learn: 1.2355967	total: 1m 53s	remaining: 1m 16s
# 300:	learn: 1.2355483	total: 1m 54s	remaining: 1m 15s
# 302:	learn: 1.2354911	total: 1m 55s	remaining: 1m 14s
# 304:	learn: 1.2354275	total: 1m 56s	remaining: 1m 14s
# 306:	learn: 1.2353876	total: 1m 56s	remaining: 1m 13s
# 308:	learn: 1.2353177	total: 1m 57s	remaining: 1m 12s
# 310:	learn: 1.2352662	total: 1m 58s	remaining: 1m 11s
# 312:	learn: 1.2352167	total: 1m 58s	remaining: 1m 10s
# 314:	learn: 1.2351688	total: 1m 59s	remaining: 1m 10s
# 316:	learn: 1.2351110	total: 2m	remaining: 1m 9s
# 318:	learn: 1.2350558	total: 2m	remaining: 1m 8s
# 320:	learn: 1.2350047	total: 2m 1s	remaining: 1m 7s
# 322:	learn: 1.2349545	total: 2m 1s	remaining: 1m 6s
# 324:	learn: 1.2349011	total: 2m 2s	remaining: 1m 6s
# 326:	learn: 1.2348420	total: 2m 3s	remaining: 1m 5s
# 328:	learn: 1.2348066	total: 2m 3s	remaining: 1m 4s
# 330:	learn: 1.2347425	total: 2m 4s	remaining: 1m 3s
# 332:	learn: 1.2346895	total: 2m 5s	remaining: 1m 3s
# 334:	learn: 1.2346340	total: 2m 6s	remaining: 1m 2s
# 336:	learn: 1.2345885	total: 2m 8s	remaining: 1m 1s
# 338:	learn: 1.2345236	total: 2m 8s	remaining: 1m 1s
# 340:	learn: 1.2344616	total: 2m 9s	remaining: 1m
# 342:	learn: 1.2344223	total: 2m 10s	remaining: 59.5s
# 344:	learn: 1.2343753	total: 2m 10s	remaining: 58.7s
# 346:	learn: 1.2343352	total: 2m 11s	remaining: 57.9s
# 348:	learn: 1.2342845	total: 2m 11s	remaining: 57.1s
# 350:	learn: 1.2342432	total: 2m 12s	remaining: 56.3s
# 352:	learn: 1.2342003	total: 2m 13s	remaining: 55.5s
# 354:	learn: 1.2341554	total: 2m 13s	remaining: 54.7s
# 356:	learn: 1.2341129	total: 2m 14s	remaining: 54s
# 358:	learn: 1.2340601	total: 2m 15s	remaining: 53.2s
# 360:	learn: 1.2340163	total: 2m 16s	remaining: 52.4s
# 362:	learn: 1.2339824	total: 2m 16s	remaining: 51.6s
# 364:	learn: 1.2339297	total: 2m 17s	remaining: 50.8s
# 366:	learn: 1.2338929	total: 2m 18s	remaining: 50.1s
# 368:	learn: 1.2338528	total: 2m 19s	remaining: 49.5s
# 370:	learn: 1.2338000	total: 2m 20s	remaining: 48.9s
# 372:	learn: 1.2337619	total: 2m 21s	remaining: 48.2s
# 374:	learn: 1.2337269	total: 2m 22s	remaining: 47.4s
# 376:	learn: 1.2336901	total: 2m 22s	remaining: 46.6s
# 378:	learn: 1.2336511	total: 2m 23s	remaining: 45.8s
# 380:	learn: 1.2336102	total: 2m 24s	remaining: 45s
# 382:	learn: 1.2335646	total: 2m 24s	remaining: 44.2s
# 384:	learn: 1.2335034	total: 2m 25s	remaining: 43.5s
# 386:	learn: 1.2334539	total: 2m 26s	remaining: 42.7s
# 388:	learn: 1.2333911	total: 2m 26s	remaining: 41.9s
# 390:	learn: 1.2333400	total: 2m 27s	remaining: 41.1s
# 392:	learn: 1.2332868	total: 2m 28s	remaining: 40.3s
# 394:	learn: 1.2332568	total: 2m 28s	remaining: 39.6s
# 396:	learn: 1.2331967	total: 2m 29s	remaining: 38.8s
# 398:	learn: 1.2331537	total: 2m 30s	remaining: 38s
# 400:	learn: 1.2330996	total: 2m 30s	remaining: 37.2s
# 402:	learn: 1.2330671	total: 2m 31s	remaining: 36.5s
# 404:	learn: 1.2330318	total: 2m 32s	remaining: 35.8s
# 406:	learn: 1.2329762	total: 2m 33s	remaining: 35.2s
# 408:	learn: 1.2329434	total: 2m 34s	remaining: 34.4s
# 410:	learn: 1.2329052	total: 2m 35s	remaining: 33.6s
# 412:	learn: 1.2328691	total: 2m 36s	remaining: 32.9s
# 414:	learn: 1.2328435	total: 2m 36s	remaining: 32.1s
# 416:	learn: 1.2328042	total: 2m 37s	remaining: 31.3s
# 418:	learn: 1.2327567	total: 2m 37s	remaining: 30.5s
# 420:	learn: 1.2327096	total: 2m 38s	remaining: 29.8s
# 422:	learn: 1.2326582	total: 2m 39s	remaining: 29s
# 424:	learn: 1.2325881	total: 2m 39s	remaining: 28.2s
# 426:	learn: 1.2325647	total: 2m 40s	remaining: 27.5s
# 428:	learn: 1.2325247	total: 2m 41s	remaining: 26.7s
# 430:	learn: 1.2324863	total: 2m 41s	remaining: 25.9s
# 432:	learn: 1.2324492	total: 2m 42s	remaining: 25.2s
# 434:	learn: 1.2324055	total: 2m 43s	remaining: 24.4s
# 436:	learn: 1.2323558	total: 2m 43s	remaining: 23.6s
# 438:	learn: 1.2323204	total: 2m 44s	remaining: 22.9s
# 440:	learn: 1.2322771	total: 2m 45s	remaining: 22.2s
# 442:	learn: 1.2322287	total: 2m 47s	remaining: 21.5s
# 444:	learn: 1.2321960	total: 2m 48s	remaining: 20.8s
# 446:	learn: 1.2321559	total: 2m 48s	remaining: 20s
# 448:	learn: 1.2321081	total: 2m 49s	remaining: 19.2s
# 450:	learn: 1.2320724	total: 2m 50s	remaining: 18.5s
# 452:	learn: 1.2320270	total: 2m 50s	remaining: 17.7s
# 454:	learn: 1.2319961	total: 2m 51s	remaining: 16.9s
# 456:	learn: 1.2319574	total: 2m 52s	remaining: 16.2s
# 458:	learn: 1.2319183	total: 2m 52s	remaining: 15.4s
# 460:	learn: 1.2318814	total: 2m 53s	remaining: 14.7s
# 462:	learn: 1.2318428	total: 2m 54s	remaining: 13.9s
# 464:	learn: 1.2318142	total: 2m 54s	remaining: 13.1s
# 466:	learn: 1.2317982	total: 2m 55s	remaining: 12.4s
# 468:	learn: 1.2317536	total: 2m 56s	remaining: 11.6s
# 470:	learn: 1.2317039	total: 2m 56s	remaining: 10.9s
# 472:	learn: 1.2316647	total: 2m 57s	remaining: 10.1s
# 474:	learn: 1.2316377	total: 2m 58s	remaining: 9.39s
# 476:	learn: 1.2316101	total: 2m 59s	remaining: 8.66s
# 478:	learn: 1.2315566	total: 3m	remaining: 7.92s
# 480:	learn: 1.2315133	total: 3m 1s	remaining: 7.17s
# 482:	learn: 1.2314701	total: 3m 2s	remaining: 6.41s
# 484:	learn: 1.2314380	total: 3m 2s	remaining: 5.65s
# 486:	learn: 1.2314037	total: 3m 3s	remaining: 4.89s
# 488:	learn: 1.2313636	total: 3m 4s	remaining: 4.14s
# 490:	learn: 1.2313187	total: 3m 4s	remaining: 3.39s
# 492:	learn: 1.2312925	total: 3m 5s	remaining: 2.63s
# 494:	learn: 1.2312438	total: 3m 6s	remaining: 1.88s
# 496:	learn: 1.2312085	total: 3m 6s	remaining: 1.13s
# 498:	learn: 1.2311737	total: 3m 7s	remaining: 376ms
# 499:	learn: 1.2311586	total: 3m 7s	remaining: 0us
# 0:	learn: 1.3688975	total: 529ms	remaining: 4m 23s
# 2:	learn: 1.3437584	total: 1.47s	remaining: 4m 4s
# 4:	learn: 1.3266220	total: 2.68s	remaining: 4m 25s
# 6:	learn: 1.3141578	total: 3.91s	remaining: 4m 35s
# 8:	learn: 1.3046807	total: 4.8s	remaining: 4m 21s
# 10:	learn: 1.2969944	total: 5.48s	remaining: 4m 3s
# 12:	learn: 1.2909081	total: 6.09s	remaining: 3m 48s
# 14:	learn: 1.2857144	total: 6.77s	remaining: 3m 38s
# 16:	learn: 1.2808605	total: 7.45s	remaining: 3m 31s
# 18:	learn: 1.2770932	total: 8.09s	remaining: 3m 24s
# 20:	learn: 1.2738929	total: 8.79s	remaining: 3m 20s
# 22:	learn: 1.2713345	total: 9.42s	remaining: 3m 15s
# 24:	learn: 1.2689388	total: 10.1s	remaining: 3m 11s
# 26:	learn: 1.2669738	total: 10.7s	remaining: 3m 8s
# 28:	learn: 1.2649629	total: 11.4s	remaining: 3m 5s
# 30:	learn: 1.2634092	total: 12s	remaining: 3m 2s
# 32:	learn: 1.2617940	total: 12.7s	remaining: 2m 59s
# 34:	learn: 1.2605474	total: 13.3s	remaining: 2m 57s
# 36:	learn: 1.2594786	total: 14s	remaining: 2m 54s
# 38:	learn: 1.2584351	total: 14.8s	remaining: 2m 54s
# 40:	learn: 1.2575910	total: 15.9s	remaining: 2m 58s
# 42:	learn: 1.2567527	total: 17.1s	remaining: 3m 1s
# 44:	learn: 1.2559865	total: 18s	remaining: 3m 1s
# 46:	learn: 1.2552309	total: 18.6s	remaining: 2m 59s
# 48:	learn: 1.2544879	total: 19.3s	remaining: 2m 57s
# 50:	learn: 1.2536917	total: 19.9s	remaining: 2m 55s
# 52:	learn: 1.2531862	total: 20.6s	remaining: 2m 53s
# 54:	learn: 1.2527309	total: 21.2s	remaining: 2m 51s
# 56:	learn: 1.2521183	total: 21.9s	remaining: 2m 50s
# 58:	learn: 1.2516515	total: 22.5s	remaining: 2m 48s
# 60:	learn: 1.2512908	total: 23.2s	remaining: 2m 46s
# 62:	learn: 1.2509773	total: 23.8s	remaining: 2m 44s
# 64:	learn: 1.2505304	total: 24.4s	remaining: 2m 43s
# 66:	learn: 1.2502444	total: 25s	remaining: 2m 41s
# 68:	learn: 1.2498659	total: 25.7s	remaining: 2m 40s
# 70:	learn: 1.2495214	total: 26.4s	remaining: 2m 39s
# 72:	learn: 1.2491140	total: 27s	remaining: 2m 37s
# 74:	learn: 1.2488307	total: 27.7s	remaining: 2m 37s
# 76:	learn: 1.2484918	total: 28.8s	remaining: 2m 38s
# 78:	learn: 1.2481858	total: 30s	remaining: 2m 39s
# 80:	learn: 1.2479160	total: 30.9s	remaining: 2m 39s
# 82:	learn: 1.2476229	total: 31.6s	remaining: 2m 38s
# 84:	learn: 1.2473909	total: 32.2s	remaining: 2m 37s
# 86:	learn: 1.2471372	total: 32.9s	remaining: 2m 36s
# 88:	learn: 1.2468809	total: 33.5s	remaining: 2m 34s
# 90:	learn: 1.2467030	total: 34.2s	remaining: 2m 33s
# 92:	learn: 1.2464865	total: 34.8s	remaining: 2m 32s
# 94:	learn: 1.2462614	total: 35.4s	remaining: 2m 31s
# 96:	learn: 1.2461027	total: 36s	remaining: 2m 29s
# 98:	learn: 1.2458644	total: 36.6s	remaining: 2m 28s
# 100:	learn: 1.2456508	total: 37.3s	remaining: 2m 27s
# 102:	learn: 1.2455241	total: 37.9s	remaining: 2m 26s
# 104:	learn: 1.2452851	total: 38.6s	remaining: 2m 25s
# 106:	learn: 1.2450833	total: 39.2s	remaining: 2m 24s
# 108:	learn: 1.2447894	total: 39.8s	remaining: 2m 22s
# 110:	learn: 1.2446492	total: 40.5s	remaining: 2m 21s
# 112:	learn: 1.2445126	total: 41.5s	remaining: 2m 21s
# 114:	learn: 1.2443520	total: 42.7s	remaining: 2m 22s
# 116:	learn: 1.2441641	total: 43.8s	remaining: 2m 23s
# 118:	learn: 1.2440158	total: 44.5s	remaining: 2m 22s
# 120:	learn: 1.2439022	total: 45.1s	remaining: 2m 21s
# 122:	learn: 1.2436936	total: 45.7s	remaining: 2m 20s
# 124:	learn: 1.2435284	total: 46.4s	remaining: 2m 19s
# 126:	learn: 1.2433406	total: 47s	remaining: 2m 18s
# 128:	learn: 1.2431950	total: 47.6s	remaining: 2m 17s
# 130:	learn: 1.2430697	total: 48.3s	remaining: 2m 15s
# 132:	learn: 1.2429127	total: 48.9s	remaining: 2m 14s
# 134:	learn: 1.2427441	total: 49.6s	remaining: 2m 14s
# 136:	learn: 1.2426048	total: 50.2s	remaining: 2m 12s
# 138:	learn: 1.2424564	total: 50.8s	remaining: 2m 12s
# 140:	learn: 1.2422722	total: 51.5s	remaining: 2m 11s
# 142:	learn: 1.2420668	total: 52.1s	remaining: 2m 10s
# 144:	learn: 1.2419143	total: 52.8s	remaining: 2m 9s
# 146:	learn: 1.2417802	total: 53.4s	remaining: 2m 8s
# 148:	learn: 1.2416390	total: 54.2s	remaining: 2m 7s
# 150:	learn: 1.2414962	total: 55.3s	remaining: 2m 7s
# 152:	learn: 1.2413996	total: 56.4s	remaining: 2m 7s
# 154:	learn: 1.2412956	total: 57.3s	remaining: 2m 7s
# 156:	learn: 1.2411418	total: 58s	remaining: 2m 6s
# 158:	learn: 1.2410457	total: 58.6s	remaining: 2m 5s
# 160:	learn: 1.2409215	total: 59.2s	remaining: 2m 4s
# 162:	learn: 1.2407909	total: 59.8s	remaining: 2m 3s
# 164:	learn: 1.2406814	total: 1m	remaining: 2m 2s
# 166:	learn: 1.2405611	total: 1m 1s	remaining: 2m 1s
# 168:	learn: 1.2404574	total: 1m 1s	remaining: 2m 1s
# 170:	learn: 1.2403088	total: 1m 2s	remaining: 2m
# 172:	learn: 1.2401853	total: 1m 3s	remaining: 1m 59s
# 174:	learn: 1.2400695	total: 1m 3s	remaining: 1m 58s
# 176:	learn: 1.2399758	total: 1m 4s	remaining: 1m 57s
# 178:	learn: 1.2399007	total: 1m 4s	remaining: 1m 56s
# 180:	learn: 1.2398081	total: 1m 5s	remaining: 1m 55s
# 182:	learn: 1.2397303	total: 1m 6s	remaining: 1m 55s
# 184:	learn: 1.2396618	total: 1m 7s	remaining: 1m 55s
# 186:	learn: 1.2395531	total: 1m 9s	remaining: 1m 55s
# 188:	learn: 1.2394324	total: 1m 11s	remaining: 1m 58s
# 190:	learn: 1.2393152	total: 1m 12s	remaining: 1m 58s
# 192:	learn: 1.2392346	total: 1m 13s	remaining: 1m 57s
# 194:	learn: 1.2390863	total: 1m 14s	remaining: 1m 56s
# 196:	learn: 1.2389311	total: 1m 14s	remaining: 1m 55s
# 198:	learn: 1.2388307	total: 1m 15s	remaining: 1m 54s
# 200:	learn: 1.2387312	total: 1m 16s	remaining: 1m 53s
# 202:	learn: 1.2386377	total: 1m 16s	remaining: 1m 52s
# 204:	learn: 1.2385357	total: 1m 17s	remaining: 1m 51s
# 206:	learn: 1.2384629	total: 1m 18s	remaining: 1m 50s
# 208:	learn: 1.2383795	total: 1m 18s	remaining: 1m 49s
# 210:	learn: 1.2383017	total: 1m 19s	remaining: 1m 48s
# 212:	learn: 1.2382068	total: 1m 20s	remaining: 1m 47s
# 214:	learn: 1.2381035	total: 1m 20s	remaining: 1m 47s
# 216:	learn: 1.2379944	total: 1m 21s	remaining: 1m 46s
# 218:	learn: 1.2379180	total: 1m 22s	remaining: 1m 45s
# 220:	learn: 1.2378211	total: 1m 22s	remaining: 1m 44s
# 222:	learn: 1.2377288	total: 1m 24s	remaining: 1m 44s
# 224:	learn: 1.2376656	total: 1m 25s	remaining: 1m 44s
# 226:	learn: 1.2375833	total: 1m 26s	remaining: 1m 43s
# 228:	learn: 1.2374968	total: 1m 26s	remaining: 1m 42s
# 230:	learn: 1.2374383	total: 1m 27s	remaining: 1m 41s
# 232:	learn: 1.2373675	total: 1m 27s	remaining: 1m 40s
# 234:	learn: 1.2373098	total: 1m 28s	remaining: 1m 39s
# 236:	learn: 1.2372366	total: 1m 29s	remaining: 1m 39s
# 238:	learn: 1.2371654	total: 1m 29s	remaining: 1m 38s
# 240:	learn: 1.2371090	total: 1m 30s	remaining: 1m 37s
# 242:	learn: 1.2370637	total: 1m 31s	remaining: 1m 36s
# 244:	learn: 1.2369852	total: 1m 31s	remaining: 1m 35s
# 246:	learn: 1.2368958	total: 1m 32s	remaining: 1m 34s
# 248:	learn: 1.2368159	total: 1m 33s	remaining: 1m 33s
# 250:	learn: 1.2367555	total: 1m 33s	remaining: 1m 33s
# 252:	learn: 1.2366925	total: 1m 34s	remaining: 1m 32s
# 254:	learn: 1.2366165	total: 1m 35s	remaining: 1m 31s
# 256:	learn: 1.2365696	total: 1m 35s	remaining: 1m 30s
# 258:	learn: 1.2364940	total: 1m 36s	remaining: 1m 30s
# 260:	learn: 1.2364316	total: 1m 38s	remaining: 1m 29s
# 262:	learn: 1.2363801	total: 1m 39s	remaining: 1m 29s
# 264:	learn: 1.2363251	total: 1m 39s	remaining: 1m 28s
# 266:	learn: 1.2362776	total: 1m 40s	remaining: 1m 27s
# 268:	learn: 1.2362285	total: 1m 40s	remaining: 1m 26s
# 270:	learn: 1.2361509	total: 1m 41s	remaining: 1m 25s
# 272:	learn: 1.2360919	total: 1m 42s	remaining: 1m 25s
# 274:	learn: 1.2360377	total: 1m 42s	remaining: 1m 24s
# 276:	learn: 1.2359946	total: 1m 43s	remaining: 1m 23s
# 278:	learn: 1.2359359	total: 1m 44s	remaining: 1m 22s
# 280:	learn: 1.2358873	total: 1m 44s	remaining: 1m 21s
# 282:	learn: 1.2358379	total: 1m 45s	remaining: 1m 20s
# 284:	learn: 1.2357561	total: 1m 46s	remaining: 1m 19s
# 286:	learn: 1.2357128	total: 1m 46s	remaining: 1m 19s
# 288:	learn: 1.2356468	total: 1m 47s	remaining: 1m 18s
# 290:	learn: 1.2355995	total: 1m 48s	remaining: 1m 17s
# 292:	learn: 1.2355469	total: 1m 48s	remaining: 1m 17s
# 294:	learn: 1.2354913	total: 1m 50s	remaining: 1m 16s
# 296:	learn: 1.2354359	total: 1m 51s	remaining: 1m 16s
# 298:	learn: 1.2353847	total: 1m 52s	remaining: 1m 15s
# 300:	learn: 1.2353336	total: 1m 52s	remaining: 1m 14s
# 302:	learn: 1.2352940	total: 1m 53s	remaining: 1m 13s
# 304:	learn: 1.2352454	total: 1m 54s	remaining: 1m 12s
# 306:	learn: 1.2351947	total: 1m 54s	remaining: 1m 12s
# 308:	learn: 1.2351431	total: 1m 55s	remaining: 1m 11s
# 310:	learn: 1.2351038	total: 1m 56s	remaining: 1m 10s
# 312:	learn: 1.2350694	total: 1m 56s	remaining: 1m 9s
# 314:	learn: 1.2350037	total: 1m 57s	remaining: 1m 8s
# 316:	learn: 1.2349439	total: 1m 58s	remaining: 1m 8s
# 318:	learn: 1.2349003	total: 1m 58s	remaining: 1m 7s
# 320:	learn: 1.2348565	total: 1m 59s	remaining: 1m 6s
# 322:	learn: 1.2348032	total: 1m 59s	remaining: 1m 5s
# 324:	learn: 1.2347584	total: 2m	remaining: 1m 4s
# 326:	learn: 1.2346996	total: 2m 1s	remaining: 1m 4s
# 328:	learn: 1.2346346	total: 2m 1s	remaining: 1m 3s
# 330:	learn: 1.2345860	total: 2m 2s	remaining: 1m 2s
# 332:	learn: 1.2345394	total: 2m 4s	remaining: 1m 2s
# 334:	learn: 1.2345093	total: 2m 5s	remaining: 1m 1s
# 336:	learn: 1.2344449	total: 2m 5s	remaining: 1m
# 338:	learn: 1.2343983	total: 2m 6s	remaining: 1m
# 340:	learn: 1.2343577	total: 2m 7s	remaining: 59.3s
# 342:	learn: 1.2342970	total: 2m 7s	remaining: 58.5s
# 344:	learn: 1.2342435	total: 2m 8s	remaining: 57.7s
# 346:	learn: 1.2342025	total: 2m 9s	remaining: 56.9s
# 348:	learn: 1.2341387	total: 2m 9s	remaining: 56.1s
# 350:	learn: 1.2341016	total: 2m 10s	remaining: 55.3s
# 352:	learn: 1.2340486	total: 2m 11s	remaining: 54.6s
# 354:	learn: 1.2339886	total: 2m 11s	remaining: 53.8s
# 356:	learn: 1.2339407	total: 2m 12s	remaining: 53s
# 358:	learn: 1.2338861	total: 2m 13s	remaining: 52.3s
# 360:	learn: 1.2338392	total: 2m 13s	remaining: 51.5s
# 362:	learn: 1.2337915	total: 2m 14s	remaining: 50.7s
# 364:	learn: 1.2337456	total: 2m 15s	remaining: 50s
# 366:	learn: 1.2336972	total: 2m 16s	remaining: 49.3s
# 368:	learn: 1.2336460	total: 2m 17s	remaining: 48.7s
# 370:	learn: 1.2336036	total: 2m 18s	remaining: 48.1s
# 372:	learn: 1.2335632	total: 2m 18s	remaining: 47.3s
# 374:	learn: 1.2335178	total: 2m 19s	remaining: 46.5s
# 376:	learn: 1.2334834	total: 2m 20s	remaining: 45.8s
# 378:	learn: 1.2334404	total: 2m 20s	remaining: 45s
# 380:	learn: 1.2333873	total: 2m 21s	remaining: 44.2s
# 382:	learn: 1.2333328	total: 2m 22s	remaining: 43.4s
# 384:	learn: 1.2332836	total: 2m 22s	remaining: 42.6s
# 386:	learn: 1.2332365	total: 2m 23s	remaining: 41.9s
# 388:	learn: 1.2331922	total: 2m 24s	remaining: 41.1s
# 390:	learn: 1.2331522	total: 2m 24s	remaining: 40.4s
# 392:	learn: 1.2331018	total: 2m 25s	remaining: 39.6s
# 394:	learn: 1.2330644	total: 2m 26s	remaining: 38.8s
# 396:	learn: 1.2330269	total: 2m 26s	remaining: 38.1s
# 398:	learn: 1.2329919	total: 2m 27s	remaining: 37.3s
# 400:	learn: 1.2329451	total: 2m 27s	remaining: 36.5s
# 402:	learn: 1.2328930	total: 2m 28s	remaining: 35.8s
# 404:	learn: 1.2328481	total: 2m 30s	remaining: 35.2s
# 406:	learn: 1.2328082	total: 2m 31s	remaining: 34.6s
# 408:	learn: 1.2327683	total: 2m 31s	remaining: 33.8s
# 410:	learn: 1.2327254	total: 2m 32s	remaining: 33s
# 412:	learn: 1.2326850	total: 2m 33s	remaining: 32.3s
# 414:	learn: 1.2326450	total: 2m 33s	remaining: 31.5s
# 416:	learn: 1.2326069	total: 2m 34s	remaining: 30.7s
# 418:	learn: 1.2325666	total: 2m 35s	remaining: 30s
# 420:	learn: 1.2325258	total: 2m 35s	remaining: 29.2s
# 422:	learn: 1.2324845	total: 2m 36s	remaining: 28.5s
# 424:	learn: 1.2324472	total: 2m 36s	remaining: 27.7s
# 426:	learn: 1.2323960	total: 2m 37s	remaining: 26.9s
# 428:	learn: 1.2323522	total: 2m 38s	remaining: 26.2s
# 430:	learn: 1.2323133	total: 2m 38s	remaining: 25.4s
# 432:	learn: 1.2322658	total: 2m 39s	remaining: 24.7s
# 434:	learn: 1.2322329	total: 2m 40s	remaining: 23.9s
# 436:	learn: 1.2321923	total: 2m 40s	remaining: 23.2s
# 438:	learn: 1.2321523	total: 2m 41s	remaining: 22.5s
# 440:	learn: 1.2321058	total: 2m 42s	remaining: 21.8s
# 442:	learn: 1.2320609	total: 2m 44s	remaining: 21.1s
# 444:	learn: 1.2320267	total: 2m 44s	remaining: 20.4s
# 446:	learn: 1.2319772	total: 2m 45s	remaining: 19.6s
# 448:	learn: 1.2319291	total: 2m 46s	remaining: 18.9s
# 450:	learn: 1.2318819	total: 2m 46s	remaining: 18.1s
# 452:	learn: 1.2318367	total: 2m 47s	remaining: 17.4s
# 454:	learn: 1.2317932	total: 2m 48s	remaining: 16.6s
# 456:	learn: 1.2317530	total: 2m 48s	remaining: 15.9s
# 458:	learn: 1.2317210	total: 2m 49s	remaining: 15.1s
# 460:	learn: 1.2316789	total: 2m 50s	remaining: 14.4s
# 462:	learn: 1.2316345	total: 2m 50s	remaining: 13.6s
# 464:	learn: 1.2315872	total: 2m 51s	remaining: 12.9s
# 466:	learn: 1.2315351	total: 2m 52s	remaining: 12.2s
# 468:	learn: 1.2314998	total: 2m 52s	remaining: 11.4s
# 470:	learn: 1.2314424	total: 2m 53s	remaining: 10.7s
# 472:	learn: 1.2313988	total: 2m 54s	remaining: 9.94s
# 474:	learn: 1.2313544	total: 2m 54s	remaining: 9.2s
# 476:	learn: 1.2313240	total: 2m 55s	remaining: 8.48s
# 478:	learn: 1.2312874	total: 2m 57s	remaining: 7.76s
# 480:	learn: 1.2312572	total: 2m 57s	remaining: 7.03s
# 482:	learn: 1.2312260	total: 2m 58s	remaining: 6.29s
# 484:	learn: 1.2311958	total: 2m 59s	remaining: 5.54s
# 486:	learn: 1.2311518	total: 2m 59s	remaining: 4.8s
# 488:	learn: 1.2311063	total: 3m	remaining: 4.06s
# 490:	learn: 1.2310494	total: 3m 1s	remaining: 3.32s
# 492:	learn: 1.2310096	total: 3m 1s	remaining: 2.58s
# 494:	learn: 1.2309707	total: 3m 2s	remaining: 1.84s
# 496:	learn: 1.2309466	total: 3m 3s	remaining: 1.1s
# 498:	learn: 1.2309058	total: 3m 3s	remaining: 368ms
# 499:	learn: 1.2308759	total: 3m 4s	remaining: 0us
# 0:	learn: 1.3688975	total: 384ms	remaining: 3m 11s
# 2:	learn: 1.3437584	total: 1.11s	remaining: 3m 3s
# 4:	learn: 1.3266220	total: 1.84s	remaining: 3m 2s
# 6:	learn: 1.3141578	total: 3.09s	remaining: 3m 37s
# 8:	learn: 1.3046807	total: 4.32s	remaining: 3m 55s
# 10:	learn: 1.2969944	total: 5.3s	remaining: 3m 55s
# 12:	learn: 1.2909081	total: 5.93s	remaining: 3m 42s
# 14:	learn: 1.2857144	total: 6.61s	remaining: 3m 33s
# 16:	learn: 1.2808605	total: 7.28s	remaining: 3m 26s
# 18:	learn: 1.2770932	total: 7.92s	remaining: 3m 20s
# 20:	learn: 1.2738929	total: 8.64s	remaining: 3m 17s
# 22:	learn: 1.2713345	total: 9.29s	remaining: 3m 12s
# 24:	learn: 1.2689388	total: 9.93s	remaining: 3m 8s
# 26:	learn: 1.2669738	total: 10.6s	remaining: 3m 5s
# 28:	learn: 1.2649629	total: 11.3s	remaining: 3m 3s
# 30:	learn: 1.2634092	total: 11.9s	remaining: 3m
# 32:	learn: 1.2617940	total: 12.6s	remaining: 2m 57s
# 34:	learn: 1.2605474	total: 13.2s	remaining: 2m 55s
# 36:	learn: 1.2594786	total: 13.9s	remaining: 2m 53s
# 38:	learn: 1.2584351	total: 14.5s	remaining: 2m 51s
# 40:	learn: 1.2575910	total: 15.3s	remaining: 2m 51s
# 42:	learn: 1.2567527	total: 16.6s	remaining: 2m 56s
# 44:	learn: 1.2559865	total: 17.8s	remaining: 2m 59s
# 46:	learn: 1.2552309	total: 18.6s	remaining: 2m 59s
# 48:	learn: 1.2544879	total: 19.3s	remaining: 2m 57s
# 50:	learn: 1.2536917	total: 20s	remaining: 2m 55s
# 52:	learn: 1.2531862	total: 20.6s	remaining: 2m 53s
# 54:	learn: 1.2527309	total: 21.2s	remaining: 2m 51s
# 56:	learn: 1.2521183	total: 21.9s	remaining: 2m 50s
# 58:	learn: 1.2516515	total: 22.5s	remaining: 2m 48s
# 60:	learn: 1.2512908	total: 23.2s	remaining: 2m 46s
# 62:	learn: 1.2509773	total: 23.8s	remaining: 2m 45s
# 64:	learn: 1.2505304	total: 24.5s	remaining: 2m 43s
# 66:	learn: 1.2502444	total: 25.1s	remaining: 2m 42s
# 68:	learn: 1.2498659	total: 25.8s	remaining: 2m 41s
# 70:	learn: 1.2495214	total: 26.4s	remaining: 2m 39s
# 72:	learn: 1.2491140	total: 27.1s	remaining: 2m 38s
# 74:	learn: 1.2488307	total: 27.7s	remaining: 2m 37s
# 76:	learn: 1.2484918	total: 28.6s	remaining: 2m 37s
# 78:	learn: 1.2481858	total: 29.8s	remaining: 2m 38s
# 80:	learn: 1.2479160	total: 30.9s	remaining: 2m 39s
# 82:	learn: 1.2476229	total: 31.8s	remaining: 2m 39s
# 84:	learn: 1.2473909	total: 32.5s	remaining: 2m 38s
# 86:	learn: 1.2471372	total: 33.1s	remaining: 2m 37s
# 88:	learn: 1.2468809	total: 33.7s	remaining: 2m 35s
# 90:	learn: 1.2467030	total: 34.4s	remaining: 2m 34s
# 92:	learn: 1.2464865	total: 35s	remaining: 2m 33s
# 94:	learn: 1.2462614	total: 35.7s	remaining: 2m 32s
# 96:	learn: 1.2461027	total: 36.3s	remaining: 2m 30s
# 98:	learn: 1.2458644	total: 36.9s	remaining: 2m 29s
# 100:	learn: 1.2456508	total: 37.6s	remaining: 2m 28s
# 102:	learn: 1.2455241	total: 38.2s	remaining: 2m 27s
# 104:	learn: 1.2452851	total: 38.9s	remaining: 2m 26s
# 106:	learn: 1.2450833	total: 39.5s	remaining: 2m 25s
# 108:	learn: 1.2447894	total: 40.2s	remaining: 2m 24s
# 110:	learn: 1.2446492	total: 40.9s	remaining: 2m 23s
# 112:	learn: 1.2445126	total: 41.5s	remaining: 2m 22s
# 114:	learn: 1.2443520	total: 42.7s	remaining: 2m 22s
# 116:	learn: 1.2441641	total: 43.9s	remaining: 2m 23s
# 118:	learn: 1.2440158	total: 44.9s	remaining: 2m 23s
# 120:	learn: 1.2439022	total: 45.5s	remaining: 2m 22s
# 122:	learn: 1.2436936	total: 46.2s	remaining: 2m 21s
# 124:	learn: 1.2435284	total: 46.8s	remaining: 2m 20s
# 126:	learn: 1.2433406	total: 47.5s	remaining: 2m 19s
# 128:	learn: 1.2431950	total: 48.1s	remaining: 2m 18s
# 130:	learn: 1.2430697	total: 48.7s	remaining: 2m 17s
# 132:	learn: 1.2429127	total: 49.3s	remaining: 2m 16s
# 134:	learn: 1.2427441	total: 50s	remaining: 2m 15s
# 136:	learn: 1.2426048	total: 50.6s	remaining: 2m 14s
# 138:	learn: 1.2424564	total: 51.3s	remaining: 2m 13s
# 140:	learn: 1.2422722	total: 51.9s	remaining: 2m 12s
# 142:	learn: 1.2420668	total: 52.6s	remaining: 2m 11s
# 144:	learn: 1.2419143	total: 53.2s	remaining: 2m 10s
# 146:	learn: 1.2417802	total: 53.8s	remaining: 2m 9s
# 148:	learn: 1.2416390	total: 54.5s	remaining: 2m 8s
# 150:	learn: 1.2414962	total: 55.5s	remaining: 2m 8s
# 152:	learn: 1.2413996	total: 56.7s	remaining: 2m 8s
# 154:	learn: 1.2412956	total: 57.8s	remaining: 2m 8s
# 156:	learn: 1.2411418	total: 58.5s	remaining: 2m 7s
# 158:	learn: 1.2410457	total: 59.1s	remaining: 2m 6s
# 160:	learn: 1.2409215	total: 59.8s	remaining: 2m 5s
# 162:	learn: 1.2407909	total: 1m	remaining: 2m 4s
# 164:	learn: 1.2406814	total: 1m 1s	remaining: 2m 3s
# 166:	learn: 1.2405611	total: 1m 1s	remaining: 2m 3s
# 168:	learn: 1.2404574	total: 1m 2s	remaining: 2m 2s
# 170:	learn: 1.2403088	total: 1m 3s	remaining: 2m 1s
# 172:	learn: 1.2401853	total: 1m 3s	remaining: 2m
# 174:	learn: 1.2400695	total: 1m 4s	remaining: 1m 59s
# 176:	learn: 1.2399758	total: 1m 4s	remaining: 1m 58s
# 178:	learn: 1.2399007	total: 1m 5s	remaining: 1m 57s
# 180:	learn: 1.2398081	total: 1m 6s	remaining: 1m 56s
# 182:	learn: 1.2397303	total: 1m 6s	remaining: 1m 55s
# 184:	learn: 1.2396618	total: 1m 7s	remaining: 1m 54s
# 186:	learn: 1.2395531	total: 1m 8s	remaining: 1m 54s
# 188:	learn: 1.2394324	total: 1m 9s	remaining: 1m 54s
# 190:	learn: 1.2393152	total: 1m 10s	remaining: 1m 54s
# 192:	learn: 1.2392346	total: 1m 11s	remaining: 1m 53s
# 194:	learn: 1.2390863	total: 1m 12s	remaining: 1m 52s
# 196:	learn: 1.2389311	total: 1m 12s	remaining: 1m 52s
# 198:	learn: 1.2388307	total: 1m 13s	remaining: 1m 51s
# 200:	learn: 1.2387312	total: 1m 14s	remaining: 1m 50s
# 202:	learn: 1.2386377	total: 1m 14s	remaining: 1m 49s
# 204:	learn: 1.2385357	total: 1m 15s	remaining: 1m 48s
# 206:	learn: 1.2384629	total: 1m 16s	remaining: 1m 47s
# 208:	learn: 1.2383795	total: 1m 16s	remaining: 1m 46s
# 210:	learn: 1.2383017	total: 1m 17s	remaining: 1m 46s
# 212:	learn: 1.2382068	total: 1m 18s	remaining: 1m 45s
# 214:	learn: 1.2381035	total: 1m 18s	remaining: 1m 44s
# 216:	learn: 1.2379944	total: 1m 19s	remaining: 1m 43s
# 218:	learn: 1.2379180	total: 1m 19s	remaining: 1m 42s
# 220:	learn: 1.2378211	total: 1m 20s	remaining: 1m 41s
# 222:	learn: 1.2377288	total: 1m 21s	remaining: 1m 41s
# 224:	learn: 1.2376656	total: 1m 22s	remaining: 1m 41s
# 226:	learn: 1.2375833	total: 1m 23s	remaining: 1m 40s
# 228:	learn: 1.2374968	total: 1m 24s	remaining: 1m 40s
# 230:	learn: 1.2374383	total: 1m 25s	remaining: 1m 39s
# 232:	learn: 1.2373675	total: 1m 25s	remaining: 1m 38s
# 234:	learn: 1.2373098	total: 1m 26s	remaining: 1m 37s
# 236:	learn: 1.2372366	total: 1m 27s	remaining: 1m 36s
# 238:	learn: 1.2371654	total: 1m 27s	remaining: 1m 36s
# 240:	learn: 1.2371090	total: 1m 28s	remaining: 1m 35s
# 242:	learn: 1.2370637	total: 1m 29s	remaining: 1m 34s
# 244:	learn: 1.2369852	total: 1m 29s	remaining: 1m 33s
# 246:	learn: 1.2368958	total: 1m 30s	remaining: 1m 32s
# 248:	learn: 1.2368159	total: 1m 31s	remaining: 1m 31s
# 250:	learn: 1.2367555	total: 1m 31s	remaining: 1m 31s
# 252:	learn: 1.2366925	total: 1m 32s	remaining: 1m 30s
# 254:	learn: 1.2366165	total: 1m 33s	remaining: 1m 29s
# 256:	learn: 1.2365696	total: 1m 33s	remaining: 1m 28s
# 258:	learn: 1.2364940	total: 1m 34s	remaining: 1m 28s
# 260:	learn: 1.2364316	total: 1m 36s	remaining: 1m 27s
# 262:	learn: 1.2363801	total: 1m 37s	remaining: 1m 27s
# 264:	learn: 1.2363251	total: 1m 38s	remaining: 1m 27s
# 266:	learn: 1.2362776	total: 1m 39s	remaining: 1m 26s
# 268:	learn: 1.2362285	total: 1m 40s	remaining: 1m 26s
# 270:	learn: 1.2361509	total: 1m 41s	remaining: 1m 25s
# 272:	learn: 1.2360919	total: 1m 41s	remaining: 1m 24s
# 274:	learn: 1.2360377	total: 1m 42s	remaining: 1m 23s
# 276:	learn: 1.2359946	total: 1m 43s	remaining: 1m 22s
# 278:	learn: 1.2359359	total: 1m 43s	remaining: 1m 22s
# 280:	learn: 1.2358873	total: 1m 44s	remaining: 1m 21s
# 282:	learn: 1.2358379	total: 1m 44s	remaining: 1m 20s
# 284:	learn: 1.2357561	total: 1m 45s	remaining: 1m 19s
# 286:	learn: 1.2357128	total: 1m 46s	remaining: 1m 18s
# 288:	learn: 1.2356468	total: 1m 46s	remaining: 1m 18s
# 290:	learn: 1.2355995	total: 1m 47s	remaining: 1m 17s
# 292:	learn: 1.2355469	total: 1m 48s	remaining: 1m 16s
# 294:	learn: 1.2354913	total: 1m 49s	remaining: 1m 16s
# 296:	learn: 1.2354359	total: 1m 50s	remaining: 1m 15s
# 298:	learn: 1.2353847	total: 1m 51s	remaining: 1m 15s
# 300:	learn: 1.2353336	total: 1m 52s	remaining: 1m 14s
# 302:	learn: 1.2352940	total: 1m 52s	remaining: 1m 13s
# 304:	learn: 1.2352454	total: 1m 53s	remaining: 1m 12s
# 306:	learn: 1.2351947	total: 1m 54s	remaining: 1m 11s
# 308:	learn: 1.2351431	total: 1m 54s	remaining: 1m 10s
# 310:	learn: 1.2351038	total: 1m 55s	remaining: 1m 10s
# 312:	learn: 1.2350694	total: 1m 55s	remaining: 1m 9s
# 314:	learn: 1.2350037	total: 1m 56s	remaining: 1m 8s
# 316:	learn: 1.2349439	total: 1m 57s	remaining: 1m 7s
# 318:	learn: 1.2349003	total: 1m 57s	remaining: 1m 6s
# 320:	learn: 1.2348565	total: 1m 58s	remaining: 1m 6s
# 322:	learn: 1.2348032	total: 1m 59s	remaining: 1m 5s
# 324:	learn: 1.2347584	total: 1m 59s	remaining: 1m 4s
# 326:	learn: 1.2346996	total: 2m	remaining: 1m 3s
# 328:	learn: 1.2346346	total: 2m 1s	remaining: 1m 2s
# 330:	learn: 1.2345860	total: 2m 2s	remaining: 1m 2s
# 332:	learn: 1.2345394	total: 2m 3s	remaining: 1m 1s
# 334:	learn: 1.2345093	total: 2m 4s	remaining: 1m 1s
# 336:	learn: 1.2344449	total: 2m 5s	remaining: 1m
# 338:	learn: 1.2343983	total: 2m 5s	remaining: 59.7s
# 340:	learn: 1.2343577	total: 2m 6s	remaining: 59s
# 342:	learn: 1.2342970	total: 2m 7s	remaining: 58.2s
# 344:	learn: 1.2342435	total: 2m 7s	remaining: 57.4s
# 346:	learn: 1.2342025	total: 2m 8s	remaining: 56.6s
# 348:	learn: 1.2341387	total: 2m 9s	remaining: 55.9s
# 350:	learn: 1.2341016	total: 2m 9s	remaining: 55.1s
# 352:	learn: 1.2340486	total: 2m 10s	remaining: 54.3s
# 354:	learn: 1.2339886	total: 2m 11s	remaining: 53.5s
# 356:	learn: 1.2339407	total: 2m 11s	remaining: 52.8s
# 358:	learn: 1.2338861	total: 2m 12s	remaining: 52s
# 360:	learn: 1.2338392	total: 2m 13s	remaining: 51.2s
# 362:	learn: 1.2337915	total: 2m 13s	remaining: 50.5s
# 364:	learn: 1.2337456	total: 2m 14s	remaining: 49.7s
# 366:	learn: 1.2336972	total: 2m 15s	remaining: 49.2s
# 368:	learn: 1.2336460	total: 2m 16s	remaining: 48.6s
# 370:	learn: 1.2336036	total: 2m 17s	remaining: 47.9s
# 372:	learn: 1.2335632	total: 2m 18s	remaining: 47.1s
# 374:	learn: 1.2335178	total: 2m 19s	remaining: 46.4s
# 376:	learn: 1.2334834	total: 2m 19s	remaining: 45.6s
# 378:	learn: 1.2334404	total: 2m 20s	remaining: 44.8s
# 380:	learn: 1.2333873	total: 2m 20s	remaining: 44s
# 382:	learn: 1.2333328	total: 2m 21s	remaining: 43.3s
# 384:	learn: 1.2332836	total: 2m 22s	remaining: 42.5s
# 386:	learn: 1.2332365	total: 2m 22s	remaining: 41.7s
# 388:	learn: 1.2331922	total: 2m 23s	remaining: 41s
# 390:	learn: 1.2331522	total: 2m 24s	remaining: 40.2s
# 392:	learn: 1.2331018	total: 2m 24s	remaining: 39.4s
# 394:	learn: 1.2330644	total: 2m 25s	remaining: 38.7s
# 396:	learn: 1.2330269	total: 2m 26s	remaining: 37.9s
# 398:	learn: 1.2329919	total: 2m 26s	remaining: 37.2s
# 400:	learn: 1.2329451	total: 2m 27s	remaining: 36.4s
# 402:	learn: 1.2328930	total: 2m 28s	remaining: 35.8s
# 404:	learn: 1.2328481	total: 2m 29s	remaining: 35.1s
# 406:	learn: 1.2328082	total: 2m 30s	remaining: 34.5s
# 408:	learn: 1.2327683	total: 2m 31s	remaining: 33.7s
# 410:	learn: 1.2327254	total: 2m 32s	remaining: 32.9s
# 412:	learn: 1.2326850	total: 2m 32s	remaining: 32.2s
# 414:	learn: 1.2326450	total: 2m 33s	remaining: 31.4s
# 416:	learn: 1.2326069	total: 2m 34s	remaining: 30.7s
# 418:	learn: 1.2325666	total: 2m 34s	remaining: 29.9s
# 420:	learn: 1.2325258	total: 2m 35s	remaining: 29.1s
# 422:	learn: 1.2324845	total: 2m 35s	remaining: 28.4s
# 424:	learn: 1.2324472	total: 2m 36s	remaining: 27.6s
# 426:	learn: 1.2323960	total: 2m 37s	remaining: 26.9s
# 428:	learn: 1.2323522	total: 2m 37s	remaining: 26.1s
# 430:	learn: 1.2323133	total: 2m 38s	remaining: 25.4s
# 432:	learn: 1.2322658	total: 2m 39s	remaining: 24.6s
# 434:	learn: 1.2322329	total: 2m 39s	remaining: 23.9s
# 436:	learn: 1.2321923	total: 2m 40s	remaining: 23.1s
# 438:	learn: 1.2321523	total: 2m 41s	remaining: 22.5s
# 440:	learn: 1.2321058	total: 2m 42s	remaining: 21.8s
# 442:	learn: 1.2320609	total: 2m 43s	remaining: 21.1s
# 444:	learn: 1.2320267	total: 2m 44s	remaining: 20.3s
# 446:	learn: 1.2319772	total: 2m 45s	remaining: 19.6s
# 448:	learn: 1.2319291	total: 2m 45s	remaining: 18.8s
# 450:	learn: 1.2318819	total: 2m 46s	remaining: 18.1s
# 452:	learn: 1.2318367	total: 2m 47s	remaining: 17.3s
# 454:	learn: 1.2317932	total: 2m 47s	remaining: 16.6s
# 456:	learn: 1.2317530	total: 2m 48s	remaining: 15.9s
# 458:	learn: 1.2317210	total: 2m 49s	remaining: 15.1s
# 460:	learn: 1.2316789	total: 2m 49s	remaining: 14.4s
# 462:	learn: 1.2316345	total: 2m 50s	remaining: 13.6s
# 464:	learn: 1.2315872	total: 2m 51s	remaining: 12.9s
# 466:	learn: 1.2315351	total: 2m 51s	remaining: 12.1s
# 468:	learn: 1.2314998	total: 2m 52s	remaining: 11.4s
# 470:	learn: 1.2314424	total: 2m 53s	remaining: 10.7s
# 472:	learn: 1.2313988	total: 2m 53s	remaining: 9.92s
# 474:	learn: 1.2313544	total: 2m 54s	remaining: 9.2s
# 476:	learn: 1.2313240	total: 2m 56s	remaining: 8.49s
# 478:	learn: 1.2312874	total: 2m 57s	remaining: 7.76s
# 480:	learn: 1.2312572	total: 2m 57s	remaining: 7.01s
# 482:	learn: 1.2312260	total: 2m 58s	remaining: 6.27s
# 484:	learn: 1.2311958	total: 2m 58s	remaining: 5.53s
# 486:	learn: 1.2311518	total: 2m 59s	remaining: 4.79s
# 488:	learn: 1.2311063	total: 3m	remaining: 4.05s
# 490:	learn: 1.2310494	total: 3m	remaining: 3.31s
# 492:	learn: 1.2310096	total: 3m 1s	remaining: 2.58s
# 494:	learn: 1.2309707	total: 3m 2s	remaining: 1.84s
# 496:	learn: 1.2309466	total: 3m 2s	remaining: 1.1s
# 498:	learn: 1.2309058	total: 3m 3s	remaining: 368ms
# 499:	learn: 1.2308759	total: 3m 3s	remaining: 0us
# RFECV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#       estimator=<catboost.core.CatBoostClassifier object at 0x7d294f029190>,
#       n_jobs=-1, scoring='accuracy', step=4)

# %% [markdown]
# Se seleccionan las columnas que le dan más peso a la clasificación

# %%
X_best = rfecv_selector.transform(X)

# %%
best_features = X.columns[rfecv_selector.support_].tolist()

# %% [markdown]
# Se reentrena con las nuevas características

# %%
X_train, X_test, y_train, y_test = train_test_split(X_best, y, test_size=0.05, random_state=42)

# %%
final_model = CatBoostClassifier(iterations=500, learning_rate=0.1, depth=6, verbose=2)
final_model.fit(X_train, y_train)
y_pred = final_model.predict(X_test)
final_accuracy = accuracy_score(y_test, y_pred)
final_accuracy
# Out:
# 0:	learn: 1.3683621	total: 740ms	remaining: 6m 9s
# 2:	learn: 1.3435806	total: 1.95s	remaining: 5m 22s
# 4:	learn: 1.3263877	total: 2.77s	remaining: 4m 33s
# 6:	learn: 1.3139188	total: 3.38s	remaining: 3m 58s
# 8:	learn: 1.3042443	total: 4.04s	remaining: 3m 40s
# 10:	learn: 1.2964747	total: 4.68s	remaining: 3m 28s
# 12:	learn: 1.2899844	total: 5.29s	remaining: 3m 18s
# 14:	learn: 1.2849966	total: 5.9s	remaining: 3m 10s
# 16:	learn: 1.2805267	total: 6.5s	remaining: 3m 4s
# 18:	learn: 1.2768391	total: 7.11s	remaining: 2m 59s
# 20:	learn: 1.2737890	total: 7.7s	remaining: 2m 55s
# 22:	learn: 1.2711305	total: 8.29s	remaining: 2m 51s
# 24:	learn: 1.2683981	total: 8.95s	remaining: 2m 49s
# 26:	learn: 1.2666502	total: 9.56s	remaining: 2m 47s
# 28:	learn: 1.2647004	total: 10.2s	remaining: 2m 45s
# 30:	learn: 1.2632108	total: 10.8s	remaining: 2m 43s
# 32:	learn: 1.2617152	total: 11.4s	remaining: 2m 41s
# 34:	learn: 1.2603474	total: 12.1s	remaining: 2m 40s
# 36:	learn: 1.2592346	total: 12.9s	remaining: 2m 41s
# 38:	learn: 1.2583250	total: 14.1s	remaining: 2m 46s
# 40:	learn: 1.2575194	total: 15.2s	remaining: 2m 50s
# 42:	learn: 1.2565959	total: 15.9s	remaining: 2m 49s
# 44:	learn: 1.2558128	total: 16.5s	remaining: 2m 47s
# 46:	learn: 1.2550248	total: 17.1s	remaining: 2m 45s
# 48:	learn: 1.2542985	total: 17.8s	remaining: 2m 43s
# 50:	learn: 1.2537145	total: 18.4s	remaining: 2m 41s
# 52:	learn: 1.2532735	total: 19s	remaining: 2m 40s
# 54:	learn: 1.2528109	total: 19.6s	remaining: 2m 38s
# 56:	learn: 1.2520742	total: 20.2s	remaining: 2m 37s
# 58:	learn: 1.2516531	total: 20.9s	remaining: 2m 35s
# 60:	learn: 1.2510872	total: 21.5s	remaining: 2m 34s
# 62:	learn: 1.2506966	total: 22.1s	remaining: 2m 33s
# 64:	learn: 1.2502886	total: 22.7s	remaining: 2m 31s
# 66:	learn: 1.2500284	total: 23.3s	remaining: 2m 30s
# 68:	learn: 1.2497782	total: 23.8s	remaining: 2m 28s
# 70:	learn: 1.2493434	total: 24.4s	remaining: 2m 27s
# 72:	learn: 1.2490693	total: 25s	remaining: 2m 26s
# 74:	learn: 1.2487053	total: 25.8s	remaining: 2m 26s
# 76:	learn: 1.2483588	total: 26.8s	remaining: 2m 27s
# 78:	learn: 1.2481156	total: 27.9s	remaining: 2m 28s
# 80:	learn: 1.2478660	total: 28.7s	remaining: 2m 28s
# 82:	learn: 1.2476119	total: 29.3s	remaining: 2m 27s
# 84:	learn: 1.2474206	total: 29.9s	remaining: 2m 26s
# 86:	learn: 1.2472208	total: 30.9s	remaining: 2m 26s
# 88:	learn: 1.2470037	total: 32.3s	remaining: 2m 28s
# 90:	learn: 1.2468056	total: 33.6s	remaining: 2m 31s
# 92:	learn: 1.2464856	total: 34.9s	remaining: 2m 32s
# 94:	learn: 1.2462228	total: 36.1s	remaining: 2m 33s
# 96:	learn: 1.2460228	total: 37.4s	remaining: 2m 35s
# 98:	learn: 1.2458386	total: 38s	remaining: 2m 34s
# 100:	learn: 1.2456756	total: 38.7s	remaining: 2m 32s
# 102:	learn: 1.2454574	total: 39.8s	remaining: 2m 33s
# 104:	learn: 1.2452185	total: 40.9s	remaining: 2m 33s
# 106:	learn: 1.2450334	total: 41.9s	remaining: 2m 33s
# 108:	learn: 1.2448186	total: 42.5s	remaining: 2m 32s
# 110:	learn: 1.2445918	total: 43.1s	remaining: 2m 30s
# 112:	learn: 1.2443763	total: 43.6s	remaining: 2m 29s
# 114:	learn: 1.2442567	total: 44.2s	remaining: 2m 28s
# 116:	learn: 1.2440998	total: 44.8s	remaining: 2m 26s
# 118:	learn: 1.2439609	total: 45.4s	remaining: 2m 25s
# 120:	learn: 1.2438054	total: 46s	remaining: 2m 24s
# 122:	learn: 1.2436429	total: 46.6s	remaining: 2m 22s
# 124:	learn: 1.2434789	total: 47.2s	remaining: 2m 21s
# 126:	learn: 1.2432885	total: 47.9s	remaining: 2m 20s
# 128:	learn: 1.2431868	total: 48.4s	remaining: 2m 19s
# 130:	learn: 1.2430044	total: 49s	remaining: 2m 18s
# 132:	learn: 1.2428169	total: 49.6s	remaining: 2m 16s
# 134:	learn: 1.2426836	total: 50.2s	remaining: 2m 15s
# 136:	learn: 1.2425755	total: 50.8s	remaining: 2m 14s
# 138:	learn: 1.2424643	total: 51.4s	remaining: 2m 13s
# 140:	learn: 1.2423283	total: 52.2s	remaining: 2m 12s
# 142:	learn: 1.2421859	total: 53.3s	remaining: 2m 13s
# 144:	learn: 1.2420141	total: 54.3s	remaining: 2m 12s
# 146:	learn: 1.2419062	total: 55.2s	remaining: 2m 12s
# 148:	learn: 1.2417938	total: 55.8s	remaining: 2m 11s
# 150:	learn: 1.2415669	total: 56.4s	remaining: 2m 10s
# 152:	learn: 1.2414322	total: 57s	remaining: 2m 9s
# 154:	learn: 1.2412728	total: 57.6s	remaining: 2m 8s
# 156:	learn: 1.2411529	total: 58.2s	remaining: 2m 7s
# 158:	learn: 1.2410290	total: 58.8s	remaining: 2m 6s
# 160:	learn: 1.2409417	total: 59.5s	remaining: 2m 5s
# 162:	learn: 1.2408203	total: 1m	remaining: 2m 4s
# 164:	learn: 1.2407375	total: 1m	remaining: 2m 3s
# 166:	learn: 1.2406201	total: 1m 1s	remaining: 2m 2s
# 168:	learn: 1.2404973	total: 1m 1s	remaining: 2m 1s
# 170:	learn: 1.2403709	total: 1m 2s	remaining: 2m
# 172:	learn: 1.2402353	total: 1m 3s	remaining: 1m 59s
# 174:	learn: 1.2401134	total: 1m 3s	remaining: 1m 58s
# 176:	learn: 1.2399923	total: 1m 4s	remaining: 1m 57s
# 178:	learn: 1.2398812	total: 1m 5s	remaining: 1m 56s
# 180:	learn: 1.2398139	total: 1m 6s	remaining: 1m 56s
# 182:	learn: 1.2397172	total: 1m 7s	remaining: 1m 56s
# 184:	learn: 1.2396466	total: 1m 8s	remaining: 1m 56s
# 186:	learn: 1.2395386	total: 1m 8s	remaining: 1m 55s
# 188:	learn: 1.2394573	total: 1m 9s	remaining: 1m 54s
# 190:	learn: 1.2393411	total: 1m 9s	remaining: 1m 53s
# 192:	learn: 1.2392642	total: 1m 10s	remaining: 1m 52s
# 194:	learn: 1.2391405	total: 1m 11s	remaining: 1m 51s
# 196:	learn: 1.2390594	total: 1m 11s	remaining: 1m 50s
# 198:	learn: 1.2389558	total: 1m 12s	remaining: 1m 49s
# 200:	learn: 1.2388930	total: 1m 12s	remaining: 1m 48s
# 202:	learn: 1.2388219	total: 1m 13s	remaining: 1m 47s
# 204:	learn: 1.2387440	total: 1m 14s	remaining: 1m 46s
# 206:	learn: 1.2386487	total: 1m 14s	remaining: 1m 45s
# 208:	learn: 1.2385796	total: 1m 15s	remaining: 1m 44s
# 210:	learn: 1.2385091	total: 1m 15s	remaining: 1m 43s
# 212:	learn: 1.2384302	total: 1m 16s	remaining: 1m 43s
# 214:	learn: 1.2383491	total: 1m 17s	remaining: 1m 42s
# 216:	learn: 1.2382759	total: 1m 17s	remaining: 1m 41s
# 218:	learn: 1.2382224	total: 1m 18s	remaining: 1m 40s
# 220:	learn: 1.2381509	total: 1m 19s	remaining: 1m 40s
# 222:	learn: 1.2380777	total: 1m 20s	remaining: 1m 40s
# 224:	learn: 1.2379895	total: 1m 21s	remaining: 1m 39s
# 226:	learn: 1.2378833	total: 1m 22s	remaining: 1m 38s
# 228:	learn: 1.2378196	total: 1m 22s	remaining: 1m 37s
# 230:	learn: 1.2377293	total: 1m 23s	remaining: 1m 37s
# 232:	learn: 1.2376772	total: 1m 23s	remaining: 1m 36s
# 234:	learn: 1.2376099	total: 1m 24s	remaining: 1m 35s
# 236:	learn: 1.2375402	total: 1m 25s	remaining: 1m 34s
# 238:	learn: 1.2374745	total: 1m 25s	remaining: 1m 33s
# 240:	learn: 1.2374139	total: 1m 26s	remaining: 1m 32s
# 242:	learn: 1.2373337	total: 1m 26s	remaining: 1m 31s
# 244:	learn: 1.2372473	total: 1m 27s	remaining: 1m 31s
# 246:	learn: 1.2371896	total: 1m 28s	remaining: 1m 30s
# 248:	learn: 1.2371183	total: 1m 28s	remaining: 1m 29s
# 250:	learn: 1.2370475	total: 1m 29s	remaining: 1m 28s
# 252:	learn: 1.2369799	total: 1m 29s	remaining: 1m 27s
# 254:	learn: 1.2368950	total: 1m 30s	remaining: 1m 26s
# 256:	learn: 1.2368407	total: 1m 31s	remaining: 1m 26s
# 258:	learn: 1.2367817	total: 1m 32s	remaining: 1m 25s
# 260:	learn: 1.2367083	total: 1m 33s	remaining: 1m 25s
# 262:	learn: 1.2366458	total: 1m 34s	remaining: 1m 25s
# 264:	learn: 1.2365918	total: 1m 34s	remaining: 1m 24s
# 266:	learn: 1.2365472	total: 1m 35s	remaining: 1m 23s
# 268:	learn: 1.2364750	total: 1m 36s	remaining: 1m 22s
# 270:	learn: 1.2364207	total: 1m 36s	remaining: 1m 21s
# 272:	learn: 1.2363660	total: 1m 37s	remaining: 1m 20s
# 274:	learn: 1.2363129	total: 1m 37s	remaining: 1m 20s
# 276:	learn: 1.2362312	total: 1m 38s	remaining: 1m 19s
# 278:	learn: 1.2361513	total: 1m 39s	remaining: 1m 18s
# 280:	learn: 1.2360900	total: 1m 39s	remaining: 1m 17s
# 282:	learn: 1.2360308	total: 1m 40s	remaining: 1m 16s
# 284:	learn: 1.2359657	total: 1m 40s	remaining: 1m 16s
# 286:	learn: 1.2359178	total: 1m 41s	remaining: 1m 15s
# 288:	learn: 1.2358740	total: 1m 42s	remaining: 1m 14s
# 290:	learn: 1.2358101	total: 1m 42s	remaining: 1m 13s
# 292:	learn: 1.2357551	total: 1m 43s	remaining: 1m 13s
# 294:	learn: 1.2357045	total: 1m 43s	remaining: 1m 12s
# 296:	learn: 1.2356371	total: 1m 44s	remaining: 1m 11s
# 298:	learn: 1.2355958	total: 1m 45s	remaining: 1m 11s
# 300:	learn: 1.2355311	total: 1m 46s	remaining: 1m 10s
# 302:	learn: 1.2354721	total: 1m 47s	remaining: 1m 10s
# 304:	learn: 1.2353931	total: 1m 48s	remaining: 1m 9s
# 306:	learn: 1.2353449	total: 1m 48s	remaining: 1m 8s
# 308:	learn: 1.2353041	total: 1m 49s	remaining: 1m 7s
# 310:	learn: 1.2352462	total: 1m 50s	remaining: 1m 6s
# 312:	learn: 1.2351775	total: 1m 50s	remaining: 1m 6s
# 314:	learn: 1.2351242	total: 1m 51s	remaining: 1m 5s
# 316:	learn: 1.2350542	total: 1m 51s	remaining: 1m 4s
# 318:	learn: 1.2349939	total: 1m 52s	remaining: 1m 3s
# 320:	learn: 1.2349365	total: 1m 53s	remaining: 1m 3s
# 322:	learn: 1.2348950	total: 1m 53s	remaining: 1m 2s
# 324:	learn: 1.2348564	total: 1m 54s	remaining: 1m 1s
# 326:	learn: 1.2347943	total: 1m 55s	remaining: 1m
# 328:	learn: 1.2347398	total: 1m 55s	remaining: 1m
# 330:	learn: 1.2346876	total: 1m 56s	remaining: 59.3s
# 332:	learn: 1.2346287	total: 1m 56s	remaining: 58.6s
# 334:	learn: 1.2345666	total: 1m 57s	remaining: 57.8s
# 336:	learn: 1.2345210	total: 1m 58s	remaining: 57.3s
# 338:	learn: 1.2344615	total: 1m 59s	remaining: 56.8s
# 340:	learn: 1.2344171	total: 2m	remaining: 56.2s
# 342:	learn: 1.2343461	total: 2m 1s	remaining: 55.5s
# 344:	learn: 1.2342875	total: 2m 1s	remaining: 54.7s
# 346:	learn: 1.2342477	total: 2m 2s	remaining: 54s
# 348:	learn: 1.2341982	total: 2m 3s	remaining: 53.2s
# 350:	learn: 1.2341529	total: 2m 3s	remaining: 52.5s
# 352:	learn: 1.2340996	total: 2m 4s	remaining: 51.8s
# 354:	learn: 1.2340520	total: 2m 4s	remaining: 51s
# 356:	learn: 1.2339955	total: 2m 5s	remaining: 50.3s
# 358:	learn: 1.2339542	total: 2m 6s	remaining: 49.5s
# 360:	learn: 1.2338923	total: 2m 6s	remaining: 48.8s
# 362:	learn: 1.2338440	total: 2m 7s	remaining: 48s
# 364:	learn: 1.2337965	total: 2m 7s	remaining: 47.3s
# 366:	learn: 1.2337410	total: 2m 8s	remaining: 46.6s
# 368:	learn: 1.2336968	total: 2m 9s	remaining: 45.8s
# 370:	learn: 1.2336561	total: 2m 9s	remaining: 45.1s
# 372:	learn: 1.2336159	total: 2m 10s	remaining: 44.4s
# 374:	learn: 1.2335781	total: 2m 11s	remaining: 43.7s
# 376:	learn: 1.2335437	total: 2m 12s	remaining: 43.1s
# 378:	learn: 1.2335014	total: 2m 13s	remaining: 42.6s
# 380:	learn: 1.2334526	total: 2m 14s	remaining: 41.9s
# 382:	learn: 1.2334148	total: 2m 14s	remaining: 41.2s
# 384:	learn: 1.2333534	total: 2m 15s	remaining: 40.5s
# 386:	learn: 1.2333050	total: 2m 16s	remaining: 39.7s
# 388:	learn: 1.2332413	total: 2m 16s	remaining: 39s
# 390:	learn: 1.2331952	total: 2m 17s	remaining: 38.3s
# 392:	learn: 1.2331436	total: 2m 17s	remaining: 37.5s
# 394:	learn: 1.2331039	total: 2m 18s	remaining: 36.8s
# 396:	learn: 1.2330565	total: 2m 19s	remaining: 36.1s
# 398:	learn: 1.2330246	total: 2m 19s	remaining: 35.4s
# 400:	learn: 1.2329728	total: 2m 20s	remaining: 34.6s
# 402:	learn: 1.2329111	total: 2m 20s	remaining: 33.9s
# 404:	learn: 1.2328726	total: 2m 21s	remaining: 33.2s
# 406:	learn: 1.2328358	total: 2m 22s	remaining: 32.5s
# 408:	learn: 1.2328084	total: 2m 22s	remaining: 31.7s
# 410:	learn: 1.2327657	total: 2m 23s	remaining: 31s
# 412:	learn: 1.2327098	total: 2m 23s	remaining: 30.3s
# 414:	learn: 1.2326723	total: 2m 25s	remaining: 29.7s
# 416:	learn: 1.2326131	total: 2m 26s	remaining: 29.1s
# 418:	learn: 1.2325630	total: 2m 27s	remaining: 28.4s
# 420:	learn: 1.2325307	total: 2m 27s	remaining: 27.7s
# 422:	learn: 1.2324894	total: 2m 28s	remaining: 27s
# 424:	learn: 1.2324327	total: 2m 28s	remaining: 26.3s
# 426:	learn: 1.2323829	total: 2m 29s	remaining: 25.6s
# 428:	learn: 1.2323388	total: 2m 30s	remaining: 24.8s
# 430:	learn: 1.2322932	total: 2m 30s	remaining: 24.1s
# 432:	learn: 1.2322385	total: 2m 31s	remaining: 23.4s
# 434:	learn: 1.2321974	total: 2m 31s	remaining: 22.7s
# 436:	learn: 1.2321600	total: 2m 32s	remaining: 22s
# 438:	learn: 1.2321155	total: 2m 33s	remaining: 21.3s
# 440:	learn: 1.2320780	total: 2m 33s	remaining: 20.6s
# 442:	learn: 1.2320352	total: 2m 34s	remaining: 19.8s
# 444:	learn: 1.2319890	total: 2m 34s	remaining: 19.1s
# 446:	learn: 1.2319451	total: 2m 35s	remaining: 18.4s
# 448:	learn: 1.2319035	total: 2m 36s	remaining: 17.7s
# 450:	learn: 1.2318673	total: 2m 36s	remaining: 17s
# 452:	learn: 1.2318234	total: 2m 37s	remaining: 16.3s
# 454:	learn: 1.2317918	total: 2m 38s	remaining: 15.7s
# 456:	learn: 1.2317417	total: 2m 39s	remaining: 15s
# 458:	learn: 1.2316994	total: 2m 40s	remaining: 14.3s
# 460:	learn: 1.2316520	total: 2m 41s	remaining: 13.6s
# 462:	learn: 1.2316008	total: 2m 41s	remaining: 12.9s
# 464:	learn: 1.2315634	total: 2m 42s	remaining: 12.2s
# 466:	learn: 1.2315286	total: 2m 42s	remaining: 11.5s
# 468:	learn: 1.2314653	total: 2m 43s	remaining: 10.8s
# 470:	learn: 1.2314232	total: 2m 44s	remaining: 10.1s
# 472:	learn: 1.2313789	total: 2m 44s	remaining: 9.4s
# 474:	learn: 1.2313472	total: 2m 45s	remaining: 8.7s
# 476:	learn: 1.2313094	total: 2m 45s	remaining: 8s
# 478:	learn: 1.2312700	total: 2m 46s	remaining: 7.3s
# 480:	learn: 1.2312293	total: 2m 47s	remaining: 6.6s
# 482:	learn: 1.2311623	total: 2m 47s	remaining: 5.9s
# 484:	learn: 1.2311261	total: 2m 48s	remaining: 5.21s
# 486:	learn: 1.2310912	total: 2m 48s	remaining: 4.51s
# 488:	learn: 1.2310509	total: 2m 49s	remaining: 3.81s
# 490:	learn: 1.2310092	total: 2m 50s	remaining: 3.12s
# 492:	learn: 1.2309715	total: 2m 51s	remaining: 2.43s
# 494:	learn: 1.2309212	total: 2m 52s	remaining: 1.74s
# 496:	learn: 1.2308882	total: 2m 53s	remaining: 1.05s
# 498:	learn: 1.2308502	total: 2m 53s	remaining: 348ms
# 499:	learn: 1.2308355	total: 2m 54s	remaining: 0us
# 0.4139783393501805

# %% [markdown]
# Se realiza la inferencia con los datos de test y se escribe el archivo para el envío

# %%
ids, test_data = preprocess_data(test_dataset, train=False)
y_pred = final_model.predict(test_data[X.columns[rfecv_selector.support_].tolist()])
y_pred = target_encoder.inverse_transform(y_pred.reshape(-1, 1))
y_pred = pd.DataFrame(y_pred, columns=['RENDIMIENTO_GLOBAL'])
submit = pd.concat([ids, y_pred], axis=1)
submit.to_csv('submission.csv', index=False)
